# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("DSC Task 1 - Absenteeism_at_work.csv")
data.head()
# Out:
#    ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0  11                  26                 7                3        1
# 1  36                   0                 7                3        1
# 2   3                  23                 7                4        1
# 3   7                   7                 7                5        1
# 4  11                  23                 7                5        1
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                     289                               36            13   33
# 1                     118                               13            18   50
# 2                     179                               51            18   38
# 3                     279                                5            14   39
# 4                     289                               36            13   33
#
#   Work load Average/day   ...  Disciplinary failure  Education  Son  \
# ...

# %%
data['Reason for absence'].value_counts()
# Out:
# 23    149
# 28    112
# 27     69
# 13     55
# 0      43
# 19     40
# 22     38
# 26     33
# 25     31
# 11     26
# 10     25
# 18     21
# 14     19
# 1      16
# 7      15
# 12      8
# 6       8
# 8       6
# 21      6
# 9       4
# 24      3
# 5       3
# 16      3
# 15      2
# 4       2
# 3       1
# 17      1
# 2       1
# Name: Reason for absence, dtype: int64

# %%
data.plot.scatter(x="ID", y="Absenteeism time in hours")
# Out:
# <AxesSubplot:xlabel='ID', ylabel='Absenteeism time in hours'>

# %%
data.plot.scatter(x="Reason for absence", y="Absenteeism time in hours")
# Out:
# <AxesSubplot:xlabel='Reason for absence', ylabel='Absenteeism time in hours'>

# %%
corrM = data.corr()

# %%
corrM
# Out:
#                                        ID  Reason for absence  \
# ID                               1.000000           -0.064245
# Reason for absence              -0.064245            1.000000
# Month of absence                -0.000043           -0.083858
# Day of the week                  0.034468            0.116319
# Seasons                          0.098495           -0.117925
# Transportation expense          -0.224163           -0.119381
# Distance from Residence to Work -0.486160            0.161831
# Service time                    -0.272704            0.048425
# Age                              0.040899           -0.078608
# Hit target                       0.018789            0.088943
# Disciplinary failure             0.004502           -0.545054
# Education                       -0.036254           -0.047357
# Son                              0.002767           -0.055364
# Social drinker                  -0.451338            0.065441
# ...

# %%
#so from matrix we can see that max factors influencing absenteeism is the reason for absence, if theyve had disciplinary failure, if
#theyve had children and their height and day of the week

# %%
data.plot.scatter(x="Day of the week", y="Absenteeism time in hours")
# Out:
# <AxesSubplot:xlabel='Day of the week', ylabel='Absenteeism time in hours'>

# %%
# so most people take off on either monday, tuesday or wednesday.

# %%
data['ID'].value_counts()
# Out:
# 3     113
# 28     76
# 34     55
# 22     46
# 20     42
# 11     40
# 15     37
# 36     34
# 24     30
# 14     29
# 33     24
# 10     24
# 1      23
# 17     20
# 5      19
# 18     16
# 13     15
# 25     10
# 6       8
# 9       8
# 23      8
# 12      7
# 30      7
# 27      7
# 2       6
# 7       6
# 26      5
# 29      5
# 32      5
# 21      3
# 31      3
# 19      3
# 8       2
# 16      2
# 4       1
# 35      1
# Name: ID, dtype: int64

# %%
data['ID'].value_counts().mean()
# Out:
# 20.555555555555557

# %%
data['ID'].value_counts().std()
# Out:
# 23.695019904063557

# %%
#ppl with above 20 leaves can be given a warning.

# %%
id3 = data.groupby('ID')

# %%
id3.get_group(3)
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 2     3                  23                 7                4        1
# 5     3                  23                 7                6        1
# 13    3                  11                 7                4        1
# 14    3                  23                 7                4        1
# 16    3                  23                 7                6        1
# ..   ..                 ...               ...              ...      ...
# 643   3                  27                 3                5        2
# 645   3                  27                 3                6        2
# 646   3                  27                 3                3        3
# 649   3                  27                 3                4        3
# 650   3                  27                 3                5        3
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# ...

# %%
id3.get_group(3)['Reason for absence'].value_counts()
# Out:
# 27    38
# 28    26
# 23    19
# 13    10
# 11     7
# 10     2
# 18     2
# 21     2
# 25     2
# 0      1
# 5      1
# 6      1
# 12     1
# 26     1
# Name: Reason for absence, dtype: int64

# %%
#So id=3 has physiotherapy and 26 dental consultations and 23 further  medical consultations. This must be further investigated
# the person could either be paid lesser or be sacked depending on value they bring.

# %%
data["Work load Average/day "]
# Out:
# 0      239,554
# 1      239,554
# 2      239,554
# 3      239,554
# 4      239,554
#         ...
# 735    264,604
# 736    264,604
# 737    271,219
# 738    271,219
# 739    271,219
# Name: Work load Average/day , Length: 740, dtype: object

# %%
data.plot.scatter(x="Work load Average/day ", y="Absenteeism time in hours")
# Out:
# <AxesSubplot:xlabel='Work load Average/day ', ylabel='Absenteeism time in hours'>

# %%
data["Work load Average/day "].value_counts()
# Out:
# 222,196    36
# 264,249    33
# 237,656    32
# 343,253    29
# 265,017    28
# 284,853    25
# 308,593    24
# 268,519    23
# 241,476    22
# 284,031    22
# 244,387    22
# 251,818    21
# 205,917    21
# 230,290    20
# 246,288    20
# 326,452    20
# 236,629    19
# 294,217    19
# 275,089    19
# 253,957    19
# 239,554    19
# 265,615    18
# 302,585    18
# 253,465    18
# 306,345    18
# 246,074    16
# 377,550    16
# 378,884    16
# 275,312    16
# 313,532    15
# 249,797    15
# 280,549    15
# 261,306    15
# 239,409    13
# 261,756    12
# 264,604    12
# 330,061    11
# 271,219     3
# Name: Work load Average/day , dtype: int64

# %%
data = data.rename(columns = {"Work load Average/day ":"workload"})

# %%
data.plot.scatter(x="Body mass index", y="Absenteeism time in hours")
# Out:
# <AxesSubplot:xlabel='Body mass index', ylabel='Absenteeism time in hours'>

# %%
data.head()
# Out:
#    ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0  11                  26                 7                3        1
# 1  36                   0                 7                3        1
# 2   3                  23                 7                4        1
# 3   7                   7                 7                5        1
# 4  11                  23                 7                5        1
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                     289                               36            13   33
# 1                     118                               13            18   50
# 2                     179                               51            18   38
# 3                     279                                5            14   39
# 4                     289                               36            13   33
#
#   workload  ...  Disciplinary failure  Education  Son  Social drinker  \
# ...

# %%
data["workload"].value_counts()
# Out:
# 222,196    36
# 264,249    33
# 237,656    32
# 343,253    29
# 265,017    28
# 284,853    25
# 308,593    24
# 268,519    23
# 241,476    22
# 284,031    22
# 244,387    22
# 251,818    21
# 205,917    21
# 230,290    20
# 246,288    20
# 326,452    20
# 236,629    19
# 294,217    19
# 275,089    19
# 253,957    19
# 239,554    19
# 265,615    18
# 302,585    18
# 253,465    18
# 306,345    18
# 246,074    16
# 377,550    16
# 378,884    16
# 275,312    16
# 313,532    15
# 249,797    15
# 280,549    15
# 261,306    15
# 239,409    13
# 261,756    12
# 264,604    12
# 330,061    11
# 271,219     3
# Name: workload, dtype: int64

# %%
data["Absenteeism time in hours"].value_counts()
# Out:
# 8      208
# 2      157
# 3      112
# 1       88
# 4       60
# 0       44
# 16      19
# 24      16
# 5        7
# 40       7
# 32       6
# 64       3
# 80       3
# 120      3
# 56       2
# 112      2
# 7        1
# 48       1
# 104      1
# Name: Absenteeism time in hours, dtype: int64

# %%
data.plot.hist(x="Reason for absence", y="Absenteeism time in hours", bins=28)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
rfa = data.groupby("Reason for absence")

# %%
rfa.mean()
# Out:
#                            ID  Month of absence  Day of the week   Seasons  \
# Reason for absence
# 0                   18.046512          7.325581         3.860465  3.162791
# 1                   21.125000          6.937500         3.187500  2.500000
# 2                   18.000000         11.000000         4.000000  4.000000
# 3                   15.000000          1.000000         4.000000  2.000000
# 4                   28.000000         11.000000         5.000000  4.000000
# 5                   24.333333          6.000000         4.333333  1.666667
# 6                   15.750000          7.750000         3.625000  2.500000
# 7                   19.266667          5.800000         3.200000  2.733333
# 8                   24.333333          6.333333         3.833333  2.333333
# 9                   27.500000          9.000000         3.000000  1.750000
# 10                  20.800000          6.240000         3.800000  2.960000
# ...

# %%
rfa.count()
# Out:
#                      ID  Month of absence  Day of the week  Seasons  \
# Reason for absence
# 0                    43                43               43       43
# 1                    16                16               16       16
# 2                     1                 1                1        1
# 3                     1                 1                1        1
# 4                     2                 2                2        2
# 5                     3                 3                3        3
# 6                     8                 8                8        8
# 7                    15                15               15       15
# 8                     6                 6                6        6
# 9                     4                 4                4        4
# 10                   25                25               25       25
# 11                   26                26               26       26
# ...

# %%
rfa.count().mean()
# Out:
# ID                                 26.428571
# Month of absence                   26.428571
# Day of the week                    26.428571
# Seasons                            26.428571
# Transportation expense             26.428571
# Distance from Residence to Work    26.428571
# Service time                       26.428571
# Age                                26.428571
# workload                           26.428571
# Hit target                         26.428571
# Disciplinary failure               26.428571
# Education                          26.428571
# Son                                26.428571
# Social drinker                     26.428571
# Social smoker                      26.428571
# Pet                                26.428571
# Weight                             26.428571
# Height                             26.428571
# Body mass index                    26.428571
# Absenteeism time in hours          26.428571
# dtype: float64

# %%
rfa.get_group(0)
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 1    36                   0                 7                3        1
# 50   20                   0                 9                2        4
# 51   29                   0                 9                2        4
# 54   11                   0                 9                3        4
# 55   36                   0                 9                3        4
# 58   13                   0                 9                4        4
# 64   36                   0                10                4        4
# 203   2                   0                 4                2        3
# 213   7                   0                 5                4        3
# 214  18                   0                 5                4        3
# 215  23                   0                 5                4        3
# 216  31                   0                 5                4        3
# ...

# %%
#therefore factors contributing to highest absenteeism are 2, 6, 9, 12 where 2 occurred only once, 6 occurred 8 times, 9 4 and 12 8

# %%
#so spreading awareness about nervous system disease-6, ear and mastoid process disease-8, circulatory system disease -9 and skin disease-12

# %%
#some of these issues like skin disease can also be resolved by improving working conditions and identifying possible health hazards.

# %%
data["workload"].dtype
# Out:
# dtype('O')

# %%
data.shape
# Out:
# (740, 21)

# %%
data.iloc[:, 9]
# Out:
# 0      239,554
# 1      239,554
# 2      239,554
# 3      239,554
# 4      239,554
#         ...
# 735    264,604
# 736    264,604
# 737    271,219
# 738    271,219
# 739    271,219
# Name: workload, Length: 740, dtype: object

# %%
for i in range(740):
    data.iloc[i, 9] = int(data.iloc[i, 9][0:3] +data.iloc[i, 9][4:] )

# %%
data["workload"].astype(str).astype(float).corr(data['Absenteeism time in hours'])
# Out:
# 0.024748899704094402

# %%
#therefore workload doesnt affect absenteeism significantly

# %%
import seaborn as sns
sns.set(rc = {'figure.figsize':(15,8)})
ax = sns.heatmap(data.corr(), annot=True)

# %%
'''INFERENCES ARE:
from matrix we can see that factors influencing absenteeism maximum are the reason for absence, if theyve had disciplinary failure, if
theyve had children and their height and day of the week 
so check for disciplinary history before hiring.
ppl with above 20 leaves can be given a warning.
if a person has above 20+1.5*23= 54.5 leave, sacking must be considered.
awareness must be increased on nervous system disease-6, ear and mastoid process disease-8, circulatory system disease -9 and skin disease-12
and it must be evaluated if working conditions are playing a factor in these diseases.
Distance to work also effects absenteeism slightly. Quarters can be given closer to workspace or they could be shifted to a branch closer.
'''
# Out:
# 'INFERENCES ARE:\nfrom matrix we can see that factors influencing absenteeism maximum are the reason for absence, if theyve had disciplinary failure, if\ntheyve had children and their height and day of the week \nso check for disciplinary history before hiring.\nppl with above 20 leaves can be given a warning.\nif a person has above 20+1.5*23= 54.5 leave, sacking must be considered.\nawareness must be increased on nervous system disease-6, ear and mastoid process disease-8, circulatory system disease -9 and skin disease-12\nand it must be evaluated if working conditions are playing a factor in these diseases.\nDistance to work also effects absenteeism slightly. Quarters can be given closer to workspace or they could be shifted to a branch closer.\n'
