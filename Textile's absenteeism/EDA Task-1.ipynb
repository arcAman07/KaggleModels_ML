# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("C:/Users/amans/Downloads/DSC Task 1 - Absenteeism_at_work.csv")

# %%
data.head()
# Out:
#    ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0  11                  26                 7                3        1
# 1  36                   0                 7                3        1
# 2   3                  23                 7                4        1
# 3   7                   7                 7                5        1
# 4  11                  23                 7                5        1
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                     289                               36            13   33
# 1                     118                               13            18   50
# 2                     179                               51            18   38
# 3                     279                                5            14   39
# 4                     289                               36            13   33
#
#   Work load Average/day   ...  Disciplinary failure  Education  Son  \
# 0                239,554  ...                     0          1    2
# 1                239,554  ...                     1          1    1
# 2                239,554  ...                     0          1    0
# 3                239,554  ...                     0          1    2
# 4                239,554  ...                     0          1    2
#
#    Social drinker  Social smoker  Pet  Weight  Height  Body mass index  \
# 0               1              0    1      90     172               30
# 1               1              0    0      98     178               31
# 2               1              0    0      89     170               31
# 3               1              1    0      68     168               24
# 4               1              0    1      90     172               30
#
#    Absenteeism time in hours
# 0                          4
# 1                          0
# 2                          2
# 3                          4
# 4                          2
#
# [5 rows x 21 columns]

# %%
data.columns
# Out:
# Index(['ID', 'Reason for absence', 'Month of absence', 'Day of the week',
#        'Seasons', 'Transportation expense', 'Distance from Residence to Work',
#        'Service time', 'Age', 'Work load Average/day ', 'Hit target',
#        'Disciplinary failure', 'Education', 'Son', 'Social drinker',
#        'Social smoker', 'Pet', 'Weight', 'Height', 'Body mass index',
#        'Absenteeism time in hours'],
#       dtype='object')

# %%
data[data.columns].isnull().sum()
# Out:
# ID                                 0
# Reason for absence                 0
# Month of absence                   0
# Day of the week                    0
# Seasons                            0
# Transportation expense             0
# Distance from Residence to Work    0
# Service time                       0
# Age                                0
# Work load Average/day              0
# Hit target                         0
# Disciplinary failure               0
# Education                          0
# Son                                0
# Social drinker                     0
# Social smoker                      0
# Pet                                0
# Weight                             0
# Height                             0
# Body mass index                    0
# Absenteeism time in hours          0
# dtype: int64

# %%
data.shape
# Out:
# (740, 21)

# %%
data.describe()
# Out:
#                ID  Reason for absence  Month of absence  Day of the week  \
# count  740.000000          740.000000        740.000000       740.000000
# mean    18.017568           19.216216          6.324324         3.914865
# std     11.021247            8.433406          3.436287         1.421675
# min      1.000000            0.000000          0.000000         2.000000
# 25%      9.000000           13.000000          3.000000         3.000000
# 50%     18.000000           23.000000          6.000000         4.000000
# 75%     28.000000           26.000000          9.000000         5.000000
# max     36.000000           28.000000         12.000000         6.000000
#
#           Seasons  Transportation expense  Distance from Residence to Work  \
# count  740.000000              740.000000                       740.000000
# mean     2.544595              221.329730                        29.631081
# std      1.111831               66.952223                        14.836788
# min      1.000000              118.000000                         5.000000
# 25%      2.000000              179.000000                        16.000000
# 50%      3.000000              225.000000                        26.000000
# 75%      4.000000              260.000000                        50.000000
# max      4.000000              388.000000                        52.000000
#
#        Service time         Age  Hit target  Disciplinary failure   Education  \
# count    740.000000  740.000000  740.000000            740.000000  740.000000
# mean      12.554054   36.450000   94.587838              0.054054    1.291892
# std        4.384873    6.478772    3.779313              0.226277    0.673238
# min        1.000000   27.000000   81.000000              0.000000    1.000000
# 25%        9.000000   31.000000   93.000000              0.000000    1.000000
# 50%       13.000000   37.000000   95.000000              0.000000    1.000000
# 75%       16.000000   40.000000   97.000000              0.000000    1.000000
# max       29.000000   58.000000  100.000000              1.000000    4.000000
#
#               Son  Social drinker  Social smoker         Pet      Weight  \
# count  740.000000      740.000000     740.000000  740.000000  740.000000
# mean     1.018919        0.567568       0.072973    0.745946   79.035135
# std      1.098489        0.495749       0.260268    1.318258   12.883211
# min      0.000000        0.000000       0.000000    0.000000   56.000000
# 25%      0.000000        0.000000       0.000000    0.000000   69.000000
# 50%      1.000000        1.000000       0.000000    0.000000   83.000000
# 75%      2.000000        1.000000       0.000000    1.000000   89.000000
# max      4.000000        1.000000       1.000000    8.000000  108.000000
#
#            Height  Body mass index  Absenteeism time in hours
# count  740.000000       740.000000                 740.000000
# mean   172.114865        26.677027                   6.924324
# std      6.034995         4.285452                  13.330998
# min    163.000000        19.000000                   0.000000
# 25%    169.000000        24.000000                   2.000000
# 50%    170.000000        25.000000                   3.000000
# 75%    172.000000        31.000000                   8.000000
# max    196.000000        38.000000                 120.000000

# %%
data['Reason for absence'].value_counts()
# Out:
# 23    149
# 28    112
# 27     69
# 13     55
# 0      43
# 19     40
# 22     38
# 26     33
# 25     31
# 11     26
# 10     25
# 18     21
# 14     19
# 1      16
# 7      15
# 6       8
# 12      8
# 21      6
# 8       6
# 9       4
# 5       3
# 16      3
# 24      3
# 15      2
# 4       2
# 3       1
# 2       1
# 17      1
# Name: Reason for absence, dtype: int64

# %%
data["Absenteeism time in hours"].describe()
# Out:
# count    740.000000
# mean       6.924324
# std       13.330998
# min        0.000000
# 25%        2.000000
# 50%        3.000000
# 75%        8.000000
# max      120.000000
# Name: Absenteeism time in hours, dtype: float64

# %%
data["Absenteeism time in hours"].value_counts()
# Out:
# 8      208
# 2      157
# 3      112
# 1       88
# 4       60
# 0       44
# 16      19
# 24      16
# 5        7
# 40       7
# 32       6
# 64       3
# 80       3
# 120      3
# 56       2
# 112      2
# 7        1
# 104      1
# 48       1
# Name: Absenteeism time in hours, dtype: int64

# %%
# It clearly looks like 7,104,48,112,56,120,80,64,32,5,40 could be outliers as less than <SD and data can be cleaned.
# But due to lack of data and lots of features, I would continue keeping the data constant as it wont have adverse affects on
# pattern we are going to see between between the features and abseentism.

# %%
# Creating Scatter Plots and Bar Plots ( to understand the data and the patterns)

# %%
data.plot.scatter(x="ID", y="Absenteeism time in hours")
# Out:
# <AxesSubplot:xlabel='ID', ylabel='Absenteeism time in hours'>

# %%
data.groupby(['ID']).count()
# Out:
#     Reason for absence  Month of absence  Day of the week  Seasons  \
# ID
# 1                   23                23               23       23
# 2                    6                 6                6        6
# 3                  113               113              113      113
# 4                    1                 1                1        1
# 5                   19                19               19       19
# 6                    8                 8                8        8
# 7                    6                 6                6        6
# 8                    2                 2                2        2
# 9                    8                 8                8        8
# 10                  24                24               24       24
# 11                  40                40               40       40
# 12                   7                 7                7        7
# 13                  15                15               15       15
# 14                  29                29               29       29
# 15                  37                37               37       37
# 16                   2                 2                2        2
# 17                  20                20               20       20
# 18                  16                16               16       16
# 19                   3                 3                3        3
# 20                  42                42               42       42
# 21                   3                 3                3        3
# 22                  46                46               46       46
# 23                   8                 8                8        8
# 24                  30                30               30       30
# 25                  10                10               10       10
# 26                   5                 5                5        5
# 27                   7                 7                7        7
# 28                  76                76               76       76
# 29                   5                 5                5        5
# 30                   7                 7                7        7
# 31                   3                 3                3        3
# 32                   5                 5                5        5
# 33                  24                24               24       24
# 34                  55                55               55       55
# 35                   1                 1                1        1
# 36                  34                34               34       34
#
#     Transportation expense  Distance from Residence to Work  Service time  \
# ID
# 1                       23                               23            23
# 2                        6                                6             6
# 3                      113                              113           113
# 4                        1                                1             1
# 5                       19                               19            19
# 6                        8                                8             8
# 7                        6                                6             6
# 8                        2                                2             2
# 9                        8                                8             8
# 10                      24                               24            24
# 11                      40                               40            40
# 12                       7                                7             7
# 13                      15                               15            15
# 14                      29                               29            29
# 15                      37                               37            37
# 16                       2                                2             2
# 17                      20                               20            20
# 18                      16                               16            16
# 19                       3                                3             3
# 20                      42                               42            42
# 21                       3                                3             3
# 22                      46                               46            46
# 23                       8                                8             8
# 24                      30                               30            30
# 25                      10                               10            10
# 26                       5                                5             5
# 27                       7                                7             7
# 28                      76                               76            76
# 29                       5                                5             5
# 30                       7                                7             7
# 31                       3                                3             3
# 32                       5                                5             5
# 33                      24                               24            24
# 34                      55                               55            55
# 35                       1                                1             1
# 36                      34                               34            34
#
#     Age  Work load Average/day   Hit target  Disciplinary failure  Education  \
# ID
# 1    23                      23          23                    23         23
# 2     6                       6           6                     6          6
# 3   113                     113         113                   113        113
# 4     1                       1           1                     1          1
# 5    19                      19          19                    19         19
# 6     8                       8           8                     8          8
# 7     6                       6           6                     6          6
# 8     2                       2           2                     2          2
# 9     8                       8           8                     8          8
# 10   24                      24          24                    24         24
# 11   40                      40          40                    40         40
# 12    7                       7           7                     7          7
# 13   15                      15          15                    15         15
# 14   29                      29          29                    29         29
# 15   37                      37          37                    37         37
# 16    2                       2           2                     2          2
# 17   20                      20          20                    20         20
# 18   16                      16          16                    16         16
# 19    3                       3           3                     3          3
# 20   42                      42          42                    42         42
# 21    3                       3           3                     3          3
# 22   46                      46          46                    46         46
# 23    8                       8           8                     8          8
# 24   30                      30          30                    30         30
# 25   10                      10          10                    10         10
# 26    5                       5           5                     5          5
# 27    7                       7           7                     7          7
# 28   76                      76          76                    76         76
# 29    5                       5           5                     5          5
# 30    7                       7           7                     7          7
# 31    3                       3           3                     3          3
# 32    5                       5           5                     5          5
# 33   24                      24          24                    24         24
# 34   55                      55          55                    55         55
# 35    1                       1           1                     1          1
# 36   34                      34          34                    34         34
#
#     Son  Social drinker  Social smoker  Pet  Weight  Height  Body mass index  \
# ID
# 1    23              23             23   23      23      23               23
# 2     6               6              6    6       6       6                6
# 3   113             113            113  113     113     113              113
# 4     1               1              1    1       1       1                1
# 5    19              19             19   19      19      19               19
# 6     8               8              8    8       8       8                8
# 7     6               6              6    6       6       6                6
# 8     2               2              2    2       2       2                2
# 9     8               8              8    8       8       8                8
# 10   24              24             24   24      24      24               24
# 11   40              40             40   40      40      40               40
# 12    7               7              7    7       7       7                7
# 13   15              15             15   15      15      15               15
# 14   29              29             29   29      29      29               29
# 15   37              37             37   37      37      37               37
# 16    2               2              2    2       2       2                2
# 17   20              20             20   20      20      20               20
# 18   16              16             16   16      16      16               16
# 19    3               3              3    3       3       3                3
# 20   42              42             42   42      42      42               42
# 21    3               3              3    3       3       3                3
# 22   46              46             46   46      46      46               46
# 23    8               8              8    8       8       8                8
# 24   30              30             30   30      30      30               30
# 25   10              10             10   10      10      10               10
# 26    5               5              5    5       5       5                5
# 27    7               7              7    7       7       7                7
# 28   76              76             76   76      76      76               76
# 29    5               5              5    5       5       5                5
# 30    7               7              7    7       7       7                7
# 31    3               3              3    3       3       3                3
# 32    5               5              5    5       5       5                5
# 33   24              24             24   24      24      24               24
# 34   55              55             55   55      55      55               55
# 35    1               1              1    1       1       1                1
# 36   34              34             34   34      34      34               34
#
#     Absenteeism time in hours
# ID
# 1                          23
# 2                           6
# 3                         113
# 4                           1
# 5                          19
# 6                           8
# 7                           6
# 8                           2
# 9                           8
# 10                         24
# 11                         40
# 12                          7
# 13                         15
# 14                         29
# 15                         37
# 16                          2
# 17                         20
# 18                         16
# 19                          3
# 20                         42
# 21                          3
# 22                         46
# 23                          8
# 24                         30
# 25                         10
# 26                          5
# 27                          7
# 28                         76
# 29                          5
# 30                          7
# 31                          3
# 32                          5
# 33                         24
# 34                         55
# 35                          1
# 36                         34

# %%
data['ID'].value_counts()
# Out:
# 3     113
# 28     76
# 34     55
# 22     46
# 20     42
# 11     40
# 15     37
# 36     34
# 24     30
# 14     29
# 33     24
# 10     24
# 1      23
# 17     20
# 5      19
# 18     16
# 13     15
# 25     10
# 9       8
# 6       8
# 23      8
# 27      7
# 12      7
# 30      7
# 2       6
# 7       6
# 26      5
# 32      5
# 29      5
# 19      3
# 21      3
# 31      3
# 8       2
# 16      2
# 4       1
# 35      1
# Name: ID, dtype: int64

# %%
plt.bar(x=data["ID"], height=data["Absenteeism time in hours"],width=0.8)
# Out:
# <BarContainer object of 740 artists>

# %%
# Here we can see there is hardly any correlation of id with the absenteeism as the data is scattered along.
# Even though a case can be made ppl with id=3 have max hours of abseentism but this feature doesnt make that sense as sd is pretty low.
# Having said that id=28 ppl should be investigated.. also id=11,22

# %%
data.groupby(['Reason for absence']).count()
# Out:
#                      ID  Month of absence  Day of the week  Seasons  \
# Reason for absence
# 0                    43                43               43       43
# 1                    16                16               16       16
# 2                     1                 1                1        1
# 3                     1                 1                1        1
# 4                     2                 2                2        2
# 5                     3                 3                3        3
# 6                     8                 8                8        8
# 7                    15                15               15       15
# 8                     6                 6                6        6
# 9                     4                 4                4        4
# 10                   25                25               25       25
# 11                   26                26               26       26
# 12                    8                 8                8        8
# 13                   55                55               55       55
# 14                   19                19               19       19
# 15                    2                 2                2        2
# 16                    3                 3                3        3
# 17                    1                 1                1        1
# 18                   21                21               21       21
# 19                   40                40               40       40
# 21                    6                 6                6        6
# 22                   38                38               38       38
# 23                  149               149              149      149
# 24                    3                 3                3        3
# 25                   31                31               31       31
# 26                   33                33               33       33
# 27                   69                69               69       69
# 28                  112               112              112      112
#
#                     Transportation expense  Distance from Residence to Work  \
# Reason for absence
# 0                                       43                               43
# 1                                       16                               16
# 2                                        1                                1
# 3                                        1                                1
# 4                                        2                                2
# 5                                        3                                3
# 6                                        8                                8
# 7                                       15                               15
# 8                                        6                                6
# 9                                        4                                4
# 10                                      25                               25
# 11                                      26                               26
# 12                                       8                                8
# 13                                      55                               55
# 14                                      19                               19
# 15                                       2                                2
# 16                                       3                                3
# 17                                       1                                1
# 18                                      21                               21
# 19                                      40                               40
# 21                                       6                                6
# 22                                      38                               38
# 23                                     149                              149
# 24                                       3                                3
# 25                                      31                               31
# 26                                      33                               33
# 27                                      69                               69
# 28                                     112                              112
#
#                     Service time  Age  Work load Average/day   Hit target  \
# Reason for absence
# 0                             43   43                      43          43
# 1                             16   16                      16          16
# 2                              1    1                       1           1
# 3                              1    1                       1           1
# 4                              2    2                       2           2
# 5                              3    3                       3           3
# 6                              8    8                       8           8
# 7                             15   15                      15          15
# 8                              6    6                       6           6
# 9                              4    4                       4           4
# 10                            25   25                      25          25
# 11                            26   26                      26          26
# 12                             8    8                       8           8
# 13                            55   55                      55          55
# 14                            19   19                      19          19
# 15                             2    2                       2           2
# 16                             3    3                       3           3
# 17                             1    1                       1           1
# 18                            21   21                      21          21
# 19                            40   40                      40          40
# 21                             6    6                       6           6
# 22                            38   38                      38          38
# 23                           149  149                     149         149
# 24                             3    3                       3           3
# 25                            31   31                      31          31
# 26                            33   33                      33          33
# 27                            69   69                      69          69
# 28                           112  112                     112         112
#
#                     Disciplinary failure  Education  Son  Social drinker  \
# Reason for absence
# 0                                     43         43   43              43
# 1                                     16         16   16              16
# 2                                      1          1    1               1
# 3                                      1          1    1               1
# 4                                      2          2    2               2
# 5                                      3          3    3               3
# 6                                      8          8    8               8
# 7                                     15         15   15              15
# 8                                      6          6    6               6
# 9                                      4          4    4               4
# 10                                    25         25   25              25
# 11                                    26         26   26              26
# 12                                     8          8    8               8
# 13                                    55         55   55              55
# 14                                    19         19   19              19
# 15                                     2          2    2               2
# 16                                     3          3    3               3
# 17                                     1          1    1               1
# 18                                    21         21   21              21
# 19                                    40         40   40              40
# 21                                     6          6    6               6
# 22                                    38         38   38              38
# 23                                   149        149  149             149
# 24                                     3          3    3               3
# 25                                    31         31   31              31
# 26                                    33         33   33              33
# 27                                    69         69   69              69
# 28                                   112        112  112             112
#
#                     Social smoker  Pet  Weight  Height  Body mass index  \
# Reason for absence
# 0                              43   43      43      43               43
# 1                              16   16      16      16               16
# 2                               1    1       1       1                1
# 3                               1    1       1       1                1
# 4                               2    2       2       2                2
# 5                               3    3       3       3                3
# 6                               8    8       8       8                8
# 7                              15   15      15      15               15
# 8                               6    6       6       6                6
# 9                               4    4       4       4                4
# 10                             25   25      25      25               25
# 11                             26   26      26      26               26
# 12                              8    8       8       8                8
# 13                             55   55      55      55               55
# 14                             19   19      19      19               19
# 15                              2    2       2       2                2
# 16                              3    3       3       3                3
# 17                              1    1       1       1                1
# 18                             21   21      21      21               21
# 19                             40   40      40      40               40
# 21                              6    6       6       6                6
# 22                             38   38      38      38               38
# 23                            149  149     149     149              149
# 24                              3    3       3       3                3
# 25                             31   31      31      31               31
# 26                             33   33      33      33               33
# 27                             69   69      69      69               69
# 28                            112  112     112     112              112
#
#                     Absenteeism time in hours
# Reason for absence
# 0                                          43
# 1                                          16
# 2                                           1
# 3                                           1
# 4                                           2
# 5                                           3
# 6                                           8
# 7                                          15
# 8                                           6
# 9                                           4
# 10                                         25
# 11                                         26
# 12                                          8
# 13                                         55
# 14                                         19
# 15                                          2
# 16                                          3
# 17                                          1
# 18                                         21
# 19                                         40
# 21                                          6
# 22                                         38
# 23                                        149
# 24                                          3
# 25                                         31
# 26                                         33
# 27                                         69
# 28                                        112

# %%
data['Reason for absence'].value_counts()
# Out:
# 23    149
# 28    112
# 27     69
# 13     55
# 0      43
# 19     40
# 22     38
# 26     33
# 25     31
# 11     26
# 10     25
# 18     21
# 14     19
# 1      16
# 7      15
# 6       8
# 12      8
# 21      6
# 8       6
# 9       4
# 5       3
# 16      3
# 24      3
# 15      2
# 4       2
# 3       1
# 2       1
# 17      1
# Name: Reason for absence, dtype: int64

# %%
data.plot.scatter(x="Reason for absence", y="Absenteeism time in hours")
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='Reason for absence', ylabel='Absenteeism time in hours'>

# %%
plt.bar(x=data["Reason for absence"], height=data["Absenteeism time in hours"],width=0.8)
# Out:
# <BarContainer object of 740 artists>

# %%
# disease number 13,19 needs awareness as for the rest leaving couple of outliers and some lack of data its pretty normal working hours

# %%
# also 14 -> Diseases of the musculoskeletal system and connective tissue,Diseases of the genitourinary system,njury, poisoning and certain other consequences of external causes

# %%
data.columns
# Out:
# Index(['ID', 'Reason for absence', 'Month of absence', 'Day of the week',
#        'Seasons', 'Transportation expense', 'Distance from Residence to Work',
#        'Service time', 'Age', 'Work load Average/day ', 'Hit target',
#        'Disciplinary failure', 'Education', 'Son', 'Social drinker',
#        'Social smoker', 'Pet', 'Weight', 'Height', 'Body mass index',
#        'Absenteeism time in hours'],
#       dtype='object')

# %%
data['Day of the week'].value_counts()
# Out:
# 2    161
# 4    156
# 3    154
# 6    144
# 5    125
# Name: Day of the week, dtype: int64

# %%
data.plot.scatter(x="Day of the week", y="Absenteeism time in hours")
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='Day of the week', ylabel='Absenteeism time in hours'>

# %%
# this shows majority of ppl take of on monday and tueday( wednesday a bit less and so on decreasing)
# which makes sense

# %%
data['Month of absence'].value_counts()
# Out:
# 3     87
# 2     72
# 10    71
# 7     67
# 5     64
# 11    63
# 8     54
# 6     54
# 9     53
# 4     53
# 1     50
# 12    49
# 0      3
# Name: Month of absence, dtype: int64

# %%
data.groupby(['Month of absence']).count()
# Out:
#                   ID  Reason for absence  Day of the week  Seasons  \
# Month of absence
# 0                  3                   3                3        3
# 1                 50                  50               50       50
# 2                 72                  72               72       72
# 3                 87                  87               87       87
# 4                 53                  53               53       53
# 5                 64                  64               64       64
# 6                 54                  54               54       54
# 7                 67                  67               67       67
# 8                 54                  54               54       54
# 9                 53                  53               53       53
# 10                71                  71               71       71
# 11                63                  63               63       63
# 12                49                  49               49       49
#
#                   Transportation expense  Distance from Residence to Work  \
# Month of absence
# 0                                      3                                3
# 1                                     50                               50
# 2                                     72                               72
# 3                                     87                               87
# 4                                     53                               53
# 5                                     64                               64
# 6                                     54                               54
# 7                                     67                               67
# 8                                     54                               54
# 9                                     53                               53
# 10                                    71                               71
# 11                                    63                               63
# 12                                    49                               49
#
#                   Service time  Age  Work load Average/day   Hit target  \
# Month of absence
# 0                            3    3                       3           3
# 1                           50   50                      50          50
# 2                           72   72                      72          72
# 3                           87   87                      87          87
# 4                           53   53                      53          53
# 5                           64   64                      64          64
# 6                           54   54                      54          54
# 7                           67   67                      67          67
# 8                           54   54                      54          54
# 9                           53   53                      53          53
# 10                          71   71                      71          71
# 11                          63   63                      63          63
# 12                          49   49                      49          49
#
#                   Disciplinary failure  Education  Son  Social drinker  \
# Month of absence
# 0                                    3          3    3               3
# 1                                   50         50   50              50
# 2                                   72         72   72              72
# 3                                   87         87   87              87
# 4                                   53         53   53              53
# 5                                   64         64   64              64
# 6                                   54         54   54              54
# 7                                   67         67   67              67
# 8                                   54         54   54              54
# 9                                   53         53   53              53
# 10                                  71         71   71              71
# 11                                  63         63   63              63
# 12                                  49         49   49              49
#
#                   Social smoker  Pet  Weight  Height  Body mass index  \
# Month of absence
# 0                             3    3       3       3                3
# 1                            50   50      50      50               50
# 2                            72   72      72      72               72
# 3                            87   87      87      87               87
# 4                            53   53      53      53               53
# 5                            64   64      64      64               64
# 6                            54   54      54      54               54
# 7                            67   67      67      67               67
# 8                            54   54      54      54               54
# 9                            53   53      53      53               53
# 10                           71   71      71      71               71
# 11                           63   63      63      63               63
# 12                           49   49      49      49               49
#
#                   Absenteeism time in hours
# Month of absence
# 0                                         3
# 1                                        50
# 2                                        72
# 3                                        87
# 4                                        53
# 5                                        64
# 6                                        54
# 7                                        67
# 8                                        54
# 9                                        53
# 10                                       71
# 11                                       63
# 12                                       49

# %%
data['']

# %%
data.plot.scatter(x="Month of absence", y="Absenteeism time in hours")
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='Month of absence', ylabel='Absenteeism time in hours'>

# %%
plt.bar(x=data["Month of absence"], height=data["Absenteeism time in hours"],width=0.8)
# Out:
# <BarContainer object of 740 artists>

# %%
# Nothing really solid can be deciphered here, where data is consistent( except month 0 which is nothing  and a peak in march but not high enough to get somewhere)

# %%
data.groupby(['Seasons']).count()
# Out:
#           ID  Reason for absence  Month of absence  Day of the week  \
# Seasons
# 1        170                 170               170              170
# 2        192                 192               192              192
# 3        183                 183               183              183
# 4        195                 195               195              195
#
#          Transportation expense  Distance from Residence to Work  \
# Seasons
# 1                           170                              170
# 2                           192                              192
# 3                           183                              183
# 4                           195                              195
#
#          Service time  Age  Work load Average/day   Hit target  \
# Seasons
# 1                 170  170                     170         170
# 2                 192  192                     192         192
# 3                 183  183                     183         183
# 4                 195  195                     195         195
#
#          Disciplinary failure  Education  Son  Social drinker  Social smoker  \
# Seasons
# 1                         170        170  170             170            170
# 2                         192        192  192             192            192
# 3                         183        183  183             183            183
# 4                         195        195  195             195            195
#
#          Pet  Weight  Height  Body mass index  Absenteeism time in hours
# Seasons
# 1        170     170     170              170                        170
# 2        192     192     192              192                        192
# 3        183     183     183              183                        183
# 4        195     195     195              195                        195

# %%
data["Seasons"].value_counts()
# Out:
# 4    195
# 2    192
# 3    183
# 1    170
# Name: Seasons, dtype: int64

# %%
data.plot.scatter(x="Seasons", y="Absenteeism time in hours")
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='Seasons', ylabel='Absenteeism time in hours'>

# %%
plt.bar(x=data["Seasons"], height=data["Absenteeism time in hours"],width=0.8)
# Out:
# <BarContainer object of 740 artists>

# %%
# Again seasons doesnt get us any pattern as its pretty consistent among the 4 seasons

# %%
data.groupby(['Transportation expense']).count()
# Out:
#                          ID  Reason for absence  Month of absence  \
# Transportation expense
# 118                      92                  92                92
# 155                      29                  29                29
# 157                       7                   7                 7
# 179                     180                 180               180
# 184                       7                   7                 7
# 189                       8                   8                 8
# 225                      81                  81                81
# 228                       8                   8                 8
# 231                       2                   2                 2
# 233                       7                   7                 7
# 235                      58                  58                58
# 246                      30                  30                30
# 248                      24                  24                24
# 260                      42                  42                42
# 268                       3                   3                 3
# 279                       6                   6                 6
# 289                      45                  45                45
# 291                      40                  40                40
# 300                       5                   5                 5
# 330                      16                  16                16
# 361                      24                  24                24
# 369                      15                  15                15
# 378                       8                   8                 8
# 388                       3                   3                 3
#
#                         Day of the week  Seasons  \
# Transportation expense
# 118                                  92       92
# 155                                  29       29
# 157                                   7        7
# 179                                 180      180
# 184                                   7        7
# 189                                   8        8
# 225                                  81       81
# 228                                   8        8
# 231                                   2        2
# 233                                   7        7
# 235                                  58       58
# 246                                  30       30
# 248                                  24       24
# 260                                  42       42
# 268                                   3        3
# 279                                   6        6
# 289                                  45       45
# 291                                  40       40
# 300                                   5        5
# 330                                  16       16
# 361                                  24       24
# 369                                  15       15
# 378                                   8        8
# 388                                   3        3
#
#                         Distance from Residence to Work  Service time  Age  \
# Transportation expense
# 118                                                  92            92   92
# 155                                                  29            29   29
# 157                                                   7             7    7
# 179                                                 180           180  180
# 184                                                   7             7    7
# 189                                                   8             8    8
# 225                                                  81            81   81
# 228                                                   8             8    8
# 231                                                   2             2    2
# 233                                                   7             7    7
# 235                                                  58            58   58
# 246                                                  30            30   30
# 248                                                  24            24   24
# 260                                                  42            42   42
# 268                                                   3             3    3
# 279                                                   6             6    6
# 289                                                  45            45   45
# 291                                                  40            40   40
# 300                                                   5             5    5
# 330                                                  16            16   16
# 361                                                  24            24   24
# 369                                                  15            15   15
# 378                                                   8             8    8
# 388                                                   3             3    3
#
#                         Work load Average/day   Hit target  \
# Transportation expense
# 118                                         92          92
# 155                                         29          29
# 157                                          7           7
# 179                                        180         180
# 184                                          7           7
# 189                                          8           8
# 225                                         81          81
# 228                                          8           8
# 231                                          2           2
# 233                                          7           7
# 235                                         58          58
# 246                                         30          30
# 248                                         24          24
# 260                                         42          42
# 268                                          3           3
# 279                                          6           6
# 289                                         45          45
# 291                                         40          40
# 300                                          5           5
# 330                                         16          16
# 361                                         24          24
# 369                                         15          15
# 378                                          8           8
# 388                                          3           3
#
#                         Disciplinary failure  Education  Son  Social drinker  \
# Transportation expense
# 118                                       92         92   92              92
# 155                                       29         29   29              29
# 157                                        7          7    7               7
# 179                                      180        180  180             180
# 184                                        7          7    7               7
# 189                                        8          8    8               8
# 225                                       81         81   81              81
# 228                                        8          8    8               8
# 231                                        2          2    2               2
# 233                                        7          7    7               7
# 235                                       58         58   58              58
# 246                                       30         30   30              30
# 248                                       24         24   24              24
# 260                                       42         42   42              42
# 268                                        3          3    3               3
# 279                                        6          6    6               6
# 289                                       45         45   45              45
# 291                                       40         40   40              40
# 300                                        5          5    5               5
# 330                                       16         16   16              16
# 361                                       24         24   24              24
# 369                                       15         15   15              15
# 378                                        8          8    8               8
# 388                                        3          3    3               3
#
#                         Social smoker  Pet  Weight  Height  Body mass index  \
# Transportation expense
# 118                                92   92      92      92               92
# 155                                29   29      29      29               29
# 157                                 7    7       7       7                7
# 179                               180  180     180     180              180
# 184                                 7    7       7       7                7
# 189                                 8    8       8       8                8
# 225                                81   81      81      81               81
# 228                                 8    8       8       8                8
# 231                                 2    2       2       2                2
# 233                                 7    7       7       7                7
# 235                                58   58      58      58               58
# 246                                30   30      30      30               30
# 248                                24   24      24      24               24
# 260                                42   42      42      42               42
# 268                                 3    3       3       3                3
# 279                                 6    6       6       6                6
# 289                                45   45      45      45               45
# 291                                40   40      40      40               40
# 300                                 5    5       5       5                5
# 330                                16   16      16      16               16
# 361                                24   24      24      24               24
# 369                                15   15      15      15               15
# 378                                 8    8       8       8                8
# 388                                 3    3       3       3                3
#
#                         Absenteeism time in hours
# Transportation expense
# 118                                            92
# 155                                            29
# 157                                             7
# 179                                           180
# 184                                             7
# 189                                             8
# 225                                            81
# 228                                             8
# 231                                             2
# 233                                             7
# 235                                            58
# 246                                            30
# 248                                            24
# 260                                            42
# 268                                             3
# 279                                             6
# 289                                            45
# 291                                            40
# 300                                             5
# 330                                            16
# 361                                            24
# 369                                            15
# 378                                             8
# 388                                             3

# %%
data["Transportation expense"].value_counts()
# Out:
# 179    180
# 118     92
# 225     81
# 235     58
# 289     45
# 260     42
# 291     40
# 246     30
# 155     29
# 361     24
# 248     24
# 330     16
# 369     15
# 228      8
# 189      8
# 378      8
# 157      7
# 184      7
# 233      7
# 279      6
# 300      5
# 388      3
# 268      3
# 231      2
# Name: Transportation expense, dtype: int64

# %%
data.plot.scatter(x="Transportation expense", y="Absenteeism time in hours")
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='Transportation expense', ylabel='Absenteeism time in hours'>

# %%
plt.bar(x=data["Transportation expense"], height=data["Absenteeism time in hours"],width=0.8)
# Out:
# <BarContainer object of 740 artists>

# %%
# interesting trend here: rather than expensive transport and more absenntess, here its kinda opposite.
# again some consistent clusters in 179, 1118 especiallu but nothing concrete can be suggested here

# %%
data.groupby(['Distance from Residence to Work']).count()
# Out:
#                                   ID  Reason for absence  Month of absence  \
# Distance from Residence to Work
# 5                                  6                   6                 6
# 10                                55                  55                55
# 11                                26                  26                26
# 12                                29                  29                29
# 13                                34                  34                34
# 14                                 9                   9                 9
# 15                                 9                   9                 9
# 16                                26                  26                26
# 17                                15                  15                15
# 20                                19                  19                19
# 22                                20                  20                20
# 25                                54                  54                54
# 26                               128                 128               128
# 27                                 7                   7                 7
# 29                                14                  14                14
# 31                                37                  37                37
# 35                                 2                   2                 2
# 36                                40                  40                40
# 42                                 7                   7                 7
# 45                                 1                   1                 1
# 48                                 5                   5                 5
# 49                                 8                   8                 8
# 50                                45                  45                45
# 51                               120                 120               120
# 52                                24                  24                24
#
#                                  Day of the week  Seasons  \
# Distance from Residence to Work
# 5                                              6        6
# 10                                            55       55
# 11                                            26       26
# 12                                            29       29
# 13                                            34       34
# 14                                             9        9
# 15                                             9        9
# 16                                            26       26
# 17                                            15       15
# 20                                            19       19
# 22                                            20       20
# 25                                            54       54
# 26                                           128      128
# 27                                             7        7
# 29                                            14       14
# 31                                            37       37
# 35                                             2        2
# 36                                            40       40
# 42                                             7        7
# 45                                             1        1
# 48                                             5        5
# 49                                             8        8
# 50                                            45       45
# 51                                           120      120
# 52                                            24       24
#
#                                  Transportation expense  Service time  Age  \
# Distance from Residence to Work
# 5                                                     6             6    6
# 10                                                   55            55   55
# 11                                                   26            26   26
# 12                                                   29            29   29
# 13                                                   34            34   34
# 14                                                    9             9    9
# 15                                                    9             9    9
# 16                                                   26            26   26
# 17                                                   15            15   15
# 20                                                   19            19   19
# 22                                                   20            20   20
# 25                                                   54            54   54
# 26                                                  128           128  128
# 27                                                    7             7    7
# 29                                                   14            14   14
# 31                                                   37            37   37
# 35                                                    2             2    2
# 36                                                   40            40   40
# 42                                                    7             7    7
# 45                                                    1             1    1
# 48                                                    5             5    5
# 49                                                    8             8    8
# 50                                                   45            45   45
# 51                                                  120           120  120
# 52                                                   24            24   24
#
#                                  Work load Average/day   Hit target  \
# Distance from Residence to Work
# 5                                                     6           6
# 10                                                   55          55
# 11                                                   26          26
# 12                                                   29          29
# 13                                                   34          34
# 14                                                    9           9
# 15                                                    9           9
# 16                                                   26          26
# 17                                                   15          15
# 20                                                   19          19
# 22                                                   20          20
# 25                                                   54          54
# 26                                                  128         128
# 27                                                    7           7
# 29                                                   14          14
# 31                                                   37          37
# 35                                                    2           2
# 36                                                   40          40
# 42                                                    7           7
# 45                                                    1           1
# 48                                                    5           5
# 49                                                    8           8
# 50                                                   45          45
# 51                                                  120         120
# 52                                                   24          24
#
#                                  Disciplinary failure  Education  Son  \
# Distance from Residence to Work
# 5                                                   6          6    6
# 10                                                 55         55   55
# 11                                                 26         26   26
# 12                                                 29         29   29
# 13                                                 34         34   34
# 14                                                  9          9    9
# 15                                                  9          9    9
# 16                                                 26         26   26
# 17                                                 15         15   15
# 20                                                 19         19   19
# 22                                                 20         20   20
# 25                                                 54         54   54
# 26                                                128        128  128
# 27                                                  7          7    7
# 29                                                 14         14   14
# 31                                                 37         37   37
# 35                                                  2          2    2
# 36                                                 40         40   40
# 42                                                  7          7    7
# 45                                                  1          1    1
# 48                                                  5          5    5
# 49                                                  8          8    8
# 50                                                 45         45   45
# 51                                                120        120  120
# 52                                                 24         24   24
#
#                                  Social drinker  Social smoker  Pet  Weight  \
# Distance from Residence to Work
# 5                                             6              6    6       6
# 10                                           55             55   55      55
# 11                                           26             26   26      26
# 12                                           29             29   29      29
# 13                                           34             34   34      34
# 14                                            9              9    9       9
# 15                                            9              9    9       9
# 16                                           26             26   26      26
# 17                                           15             15   15      15
# 20                                           19             19   19      19
# 22                                           20             20   20      20
# 25                                           54             54   54      54
# 26                                          128            128  128     128
# 27                                            7              7    7       7
# 29                                           14             14   14      14
# 31                                           37             37   37      37
# 35                                            2              2    2       2
# 36                                           40             40   40      40
# 42                                            7              7    7       7
# 45                                            1              1    1       1
# 48                                            5              5    5       5
# 49                                            8              8    8       8
# 50                                           45             45   45      45
# 51                                          120            120  120     120
# 52                                           24             24   24      24
#
#                                  Height  Body mass index  \
# Distance from Residence to Work
# 5                                     6                6
# 10                                   55               55
# 11                                   26               26
# 12                                   29               29
# 13                                   34               34
# 14                                    9                9
# 15                                    9                9
# 16                                   26               26
# 17                                   15               15
# 20                                   19               19
# 22                                   20               20
# 25                                   54               54
# 26                                  128              128
# 27                                    7                7
# 29                                   14               14
# 31                                   37               37
# 35                                    2                2
# 36                                   40               40
# 42                                    7                7
# 45                                    1                1
# 48                                    5                5
# 49                                    8                8
# 50                                   45               45
# 51                                  120              120
# 52                                   24               24
#
#                                  Absenteeism time in hours
# Distance from Residence to Work
# 5                                                        6
# 10                                                      55
# 11                                                      26
# 12                                                      29
# 13                                                      34
# 14                                                       9
# 15                                                       9
# 16                                                      26
# 17                                                      15
# 20                                                      19
# 22                                                      20
# 25                                                      54
# 26                                                     128
# 27                                                       7
# 29                                                      14
# 31                                                      37
# 35                                                       2
# 36                                                      40
# 42                                                       7
# 45                                                       1
# 48                                                       5
# 49                                                       8
# 50                                                      45
# 51                                                     120
# 52                                                      24

# %%
data["Distance from Residence to Work"].value_counts()
# Out:
# 26    128
# 51    120
# 10     55
# 25     54
# 50     45
# 36     40
# 31     37
# 13     34
# 12     29
# 11     26
# 16     26
# 52     24
# 22     20
# 20     19
# 17     15
# 29     14
# 15      9
# 14      9
# 49      8
# 42      7
# 27      7
# 5       6
# 48      5
# 35      2
# 45      1
# Name: Distance from Residence to Work, dtype: int64

# %%
data.plot.scatter(x="Distance from Residence to Work", y="Absenteeism time in hours")
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='Distance from Residence to Work', ylabel='Absenteeism time in hours'>

# %%
plt.bar(x=data["Distance from Residence to Work"], height=data["Absenteeism time in hours"],width=0.8)
# Out:
# <BarContainer object of 740 artists>

# %%
# again nothing concrete can be established

# %%
data.groupby(['Service time']).count()
# Out:
#                ID  Reason for absence  Month of absence  Day of the week  \
# Service time
# 1               7                   7                 7                7
# 3              24                  24                24               24
# 4              16                  16                16               16
# 6               7                   7                 7                7
# 7               7                   7                 7                7
# 8              13                  13                13               13
# 9             126                 126               126              126
# 10             55                  55                55               55
# 11             50                  50                50               50
# 12             61                  61                61               61
# 13             73                  73                73               73
# 14             85                  85                85               85
# 15              4                   4                 4                4
# 16             38                  38                38               38
# 17             20                  20                20               20
# 18            147                 147               147              147
# 24              2                   2                 2                2
# 29              5                   5                 5                5
#
#               Seasons  Transportation expense  \
# Service time
# 1                   7                       7
# 3                  24                      24
# 4                  16                      16
# 6                   7                       7
# 7                   7                       7
# 8                  13                      13
# 9                 126                     126
# 10                 55                      55
# 11                 50                      50
# 12                 61                      61
# 13                 73                      73
# 14                 85                      85
# 15                  4                       4
# 16                 38                      38
# 17                 20                      20
# 18                147                     147
# 24                  2                       2
# 29                  5                       5
#
#               Distance from Residence to Work  Age  Work load Average/day   \
# Service time
# 1                                           7    7                       7
# 3                                          24   24                      24
# 4                                          16   16                      16
# 6                                           7    7                       7
# 7                                           7    7                       7
# 8                                          13   13                      13
# 9                                         126  126                     126
# 10                                         55   55                      55
# 11                                         50   50                      50
# 12                                         61   61                      61
# 13                                         73   73                      73
# 14                                         85   85                      85
# 15                                          4    4                       4
# 16                                         38   38                      38
# 17                                         20   20                      20
# 18                                        147  147                     147
# 24                                          2    2                       2
# 29                                          5    5                       5
#
#               Hit target  Disciplinary failure  Education  Son  \
# Service time
# 1                      7                     7          7    7
# 3                     24                    24         24   24
# 4                     16                    16         16   16
# 6                      7                     7          7    7
# 7                      7                     7          7    7
# 8                     13                    13         13   13
# 9                    126                   126        126  126
# 10                    55                    55         55   55
# 11                    50                    50         50   50
# 12                    61                    61         61   61
# 13                    73                    73         73   73
# 14                    85                    85         85   85
# 15                     4                     4          4    4
# 16                    38                    38         38   38
# 17                    20                    20         20   20
# 18                   147                   147        147  147
# 24                     2                     2          2    2
# 29                     5                     5          5    5
#
#               Social drinker  Social smoker  Pet  Weight  Height  \
# Service time
# 1                          7              7    7       7       7
# 3                         24             24   24      24      24
# 4                         16             16   16      16      16
# 6                          7              7    7       7       7
# 7                          7              7    7       7       7
# 8                         13             13   13      13      13
# 9                        126            126  126     126     126
# 10                        55             55   55      55      55
# 11                        50             50   50      50      50
# 12                        61             61   61      61      61
# 13                        73             73   73      73      73
# 14                        85             85   85      85      85
# 15                         4              4    4       4       4
# 16                        38             38   38      38      38
# 17                        20             20   20      20      20
# 18                       147            147  147     147     147
# 24                         2              2    2       2       2
# 29                         5              5    5       5       5
#
#               Body mass index  Absenteeism time in hours
# Service time
# 1                           7                          7
# 3                          24                         24
# 4                          16                         16
# 6                           7                          7
# 7                           7                          7
# 8                          13                         13
# 9                         126                        126
# 10                         55                         55
# 11                         50                         50
# 12                         61                         61
# 13                         73                         73
# 14                         85                         85
# 15                          4                          4
# 16                         38                         38
# 17                         20                         20
# 18                        147                        147
# 24                          2                          2
# 29                          5                          5

# %%
data["Service time"].value_counts()
# Out:
# 18    147
# 9     126
# 14     85
# 13     73
# 12     61
# 10     55
# 11     50
# 16     38
# 3      24
# 17     20
# 4      16
# 8      13
# 1       7
# 7       7
# 6       7
# 29      5
# 15      4
# 24      2
# Name: Service time, dtype: int64

# %%
data.plot.scatter(x="Service time", y="Absenteeism time in hours")
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='Service time', ylabel='Absenteeism time in hours'>

# %%
plt.bar(x=data["Service time"], height=data["Absenteeism time in hours"],width=0.8)
# Out:
# <BarContainer object of 740 artists>

# %%
# between 10 and 18 the ansenetism , so keeping the service below or above could be tested for some of the employees,

# %%
data.groupby(['Age']).count()
# Out:
#       ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# Age
# 27     7                   7                 7                7        7
# 28   117                 117               117              117      117
# 29     7                   7                 7                7        7
# 30    46                  46                46               46       46
# 31    22                  22                22               22       22
# 32    13                  13                13               13       13
# 33    51                  51                51               51       51
# 34    29                  29                29               29       29
# 36    50                  50                50               50       50
# 37    78                  78                78               78       78
# 38   113                 113               113              113      113
# 39     8                   8                 8                8        8
# 40    58                  58                58               58       58
# 41    34                  34                34               34       34
# 43    24                  24                24               24       24
# 46     2                   2                 2                2        2
# 47    24                  24                24               24       24
# 48     6                   6                 6                6        6
# 49     5                   5                 5                5        5
# 50    37                  37                37               37       37
# 53     1                   1                 1                1        1
# 58     8                   8                 8                8        8
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# Age
# 27                        7                                7             7
# 28                      117                              117           117
# 29                        7                                7             7
# 30                       46                               46            46
# 31                       22                               22            22
# 32                       13                               13            13
# 33                       51                               51            51
# 34                       29                               29            29
# 36                       50                               50            50
# 37                       78                               78            78
# 38                      113                              113           113
# 39                        8                                8             8
# 40                       58                               58            58
# 41                       34                               34            34
# 43                       24                               24            24
# 46                        2                                2             2
# 47                       24                               24            24
# 48                        6                                6             6
# 49                        5                                5             5
# 50                       37                               37            37
# 53                        1                                1             1
# 58                        8                                8             8
#
#      Work load Average/day   Hit target  Disciplinary failure  Education  Son  \
# Age
# 27                        7           7                     7          7    7
# 28                      117         117                   117        117  117
# 29                        7           7                     7          7    7
# 30                       46          46                    46         46   46
# 31                       22          22                    22         22   22
# 32                       13          13                    13         13   13
# 33                       51          51                    51         51   51
# 34                       29          29                    29         29   29
# 36                       50          50                    50         50   50
# 37                       78          78                    78         78   78
# 38                      113         113                   113        113  113
# 39                        8           8                     8          8    8
# 40                       58          58                    58         58   58
# 41                       34          34                    34         34   34
# 43                       24          24                    24         24   24
# 46                        2           2                     2          2    2
# 47                       24          24                    24         24   24
# 48                        6           6                     6          6    6
# 49                        5           5                     5          5    5
# 50                       37          37                    37         37   37
# 53                        1           1                     1          1    1
# 58                        8           8                     8          8    8
#
#      Social drinker  Social smoker  Pet  Weight  Height  Body mass index  \
# Age
# 27                7              7    7       7       7                7
# 28              117            117  117     117     117              117
# 29                7              7    7       7       7                7
# 30               46             46   46      46      46               46
# 31               22             22   22      22      22               22
# 32               13             13   13      13      13               13
# 33               51             51   51      51      51               51
# 34               29             29   29      29      29               29
# 36               50             50   50      50      50               50
# 37               78             78   78      78      78               78
# 38              113            113  113     113     113              113
# 39                8              8    8       8       8                8
# 40               58             58   58      58      58               58
# 41               34             34   34      34      34               34
# 43               24             24   24      24      24               24
# 46                2              2    2       2       2                2
# 47               24             24   24      24      24               24
# 48                6              6    6       6       6                6
# 49                5              5    5       5       5                5
# 50               37             37   37      37      37               37
# 53                1              1    1       1       1                1
# 58                8              8    8       8       8                8
#
#      Absenteeism time in hours
# Age
# 27                           7
# 28                         117
# 29                           7
# 30                          46
# 31                          22
# 32                          13
# 33                          51
# 34                          29
# 36                          50
# 37                          78
# 38                         113
# 39                           8
# 40                          58
# 41                          34
# 43                          24
# 46                           2
# 47                          24
# 48                           6
# 49                           5
# 50                          37
# 53                           1
# 58                           8

# %%
data["Age"].value_counts()
# Out:
# 28    117
# 38    113
# 37     78
# 40     58
# 33     51
# 36     50
# 30     46
# 50     37
# 41     34
# 34     29
# 43     24
# 47     24
# 31     22
# 32     13
# 58      8
# 39      8
# 29      7
# 27      7
# 48      6
# 49      5
# 46      2
# 53      1
# Name: Age, dtype: int64

# %%
data.plot.scatter(x="Age", y="Absenteeism time in hours")
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='Age', ylabel='Absenteeism time in hours'>

# %%
plt.bar(x=data["Age"], height=data["Absenteeism time in hours"],width=0.8)
# Out:
# <BarContainer object of 740 artists>

# %%
# this data just tells us out employyes who have just joined( or a bit young) and old emplyees( having family ) tend to
# to be less absent and follow their work. While in the age clusters of mid thirties we can see fluctuations but nothing too concrete 
# take a decison

# %%
data.groupby(['Work load Average/day ']).count()
# Out:
#                         ID  Reason for absence  Month of absence  \
# Work load Average/day
# 205,917                 21                  21                21
# 222,196                 36                  36                36
# 230,290                 20                  20                20
# 236,629                 19                  19                19
# 237,656                 32                  32                32
# 239,409                 13                  13                13
# 239,554                 19                  19                19
# 241,476                 22                  22                22
# 244,387                 22                  22                22
# 246,074                 16                  16                16
# 246,288                 20                  20                20
# 249,797                 15                  15                15
# 251,818                 21                  21                21
# 253,465                 18                  18                18
# 253,957                 19                  19                19
# 261,306                 15                  15                15
# 261,756                 12                  12                12
# 264,249                 33                  33                33
# 264,604                 12                  12                12
# 265,017                 28                  28                28
# 265,615                 18                  18                18
# 268,519                 23                  23                23
# 271,219                  3                   3                 3
# 275,089                 19                  19                19
# 275,312                 16                  16                16
# 280,549                 15                  15                15
# 284,031                 22                  22                22
# 284,853                 25                  25                25
# 294,217                 19                  19                19
# 302,585                 18                  18                18
# 306,345                 18                  18                18
# 308,593                 24                  24                24
# 313,532                 15                  15                15
# 326,452                 20                  20                20
# 330,061                 11                  11                11
# 343,253                 29                  29                29
# 377,550                 16                  16                16
# 378,884                 16                  16                16
#
#                         Day of the week  Seasons  Transportation expense  \
# Work load Average/day
# 205,917                              21       21                      21
# 222,196                              36       36                      36
# 230,290                              20       20                      20
# 236,629                              19       19                      19
# 237,656                              32       32                      32
# 239,409                              13       13                      13
# 239,554                              19       19                      19
# 241,476                              22       22                      22
# 244,387                              22       22                      22
# 246,074                              16       16                      16
# 246,288                              20       20                      20
# 249,797                              15       15                      15
# 251,818                              21       21                      21
# 253,465                              18       18                      18
# 253,957                              19       19                      19
# 261,306                              15       15                      15
# 261,756                              12       12                      12
# 264,249                              33       33                      33
# 264,604                              12       12                      12
# 265,017                              28       28                      28
# 265,615                              18       18                      18
# 268,519                              23       23                      23
# 271,219                               3        3                       3
# 275,089                              19       19                      19
# 275,312                              16       16                      16
# 280,549                              15       15                      15
# 284,031                              22       22                      22
# 284,853                              25       25                      25
# 294,217                              19       19                      19
# 302,585                              18       18                      18
# 306,345                              18       18                      18
# 308,593                              24       24                      24
# 313,532                              15       15                      15
# 326,452                              20       20                      20
# 330,061                              11       11                      11
# 343,253                              29       29                      29
# 377,550                              16       16                      16
# 378,884                              16       16                      16
#
#                         Distance from Residence to Work  Service time  Age  \
# Work load Average/day
# 205,917                                              21            21   21
# 222,196                                              36            36   36
# 230,290                                              20            20   20
# 236,629                                              19            19   19
# 237,656                                              32            32   32
# 239,409                                              13            13   13
# 239,554                                              19            19   19
# 241,476                                              22            22   22
# 244,387                                              22            22   22
# 246,074                                              16            16   16
# 246,288                                              20            20   20
# 249,797                                              15            15   15
# 251,818                                              21            21   21
# 253,465                                              18            18   18
# 253,957                                              19            19   19
# 261,306                                              15            15   15
# 261,756                                              12            12   12
# 264,249                                              33            33   33
# 264,604                                              12            12   12
# 265,017                                              28            28   28
# 265,615                                              18            18   18
# 268,519                                              23            23   23
# 271,219                                               3             3    3
# 275,089                                              19            19   19
# 275,312                                              16            16   16
# 280,549                                              15            15   15
# 284,031                                              22            22   22
# 284,853                                              25            25   25
# 294,217                                              19            19   19
# 302,585                                              18            18   18
# 306,345                                              18            18   18
# 308,593                                              24            24   24
# 313,532                                              15            15   15
# 326,452                                              20            20   20
# 330,061                                              11            11   11
# 343,253                                              29            29   29
# 377,550                                              16            16   16
# 378,884                                              16            16   16
#
#                         Hit target  Disciplinary failure  Education  Son  \
# Work load Average/day
# 205,917                         21                    21         21   21
# 222,196                         36                    36         36   36
# 230,290                         20                    20         20   20
# 236,629                         19                    19         19   19
# 237,656                         32                    32         32   32
# 239,409                         13                    13         13   13
# 239,554                         19                    19         19   19
# 241,476                         22                    22         22   22
# 244,387                         22                    22         22   22
# 246,074                         16                    16         16   16
# 246,288                         20                    20         20   20
# 249,797                         15                    15         15   15
# 251,818                         21                    21         21   21
# 253,465                         18                    18         18   18
# 253,957                         19                    19         19   19
# 261,306                         15                    15         15   15
# 261,756                         12                    12         12   12
# 264,249                         33                    33         33   33
# 264,604                         12                    12         12   12
# 265,017                         28                    28         28   28
# 265,615                         18                    18         18   18
# 268,519                         23                    23         23   23
# 271,219                          3                     3          3    3
# 275,089                         19                    19         19   19
# 275,312                         16                    16         16   16
# 280,549                         15                    15         15   15
# 284,031                         22                    22         22   22
# 284,853                         25                    25         25   25
# 294,217                         19                    19         19   19
# 302,585                         18                    18         18   18
# 306,345                         18                    18         18   18
# 308,593                         24                    24         24   24
# 313,532                         15                    15         15   15
# 326,452                         20                    20         20   20
# 330,061                         11                    11         11   11
# 343,253                         29                    29         29   29
# 377,550                         16                    16         16   16
# 378,884                         16                    16         16   16
#
#                         Social drinker  Social smoker  Pet  Weight  Height  \
# Work load Average/day
# 205,917                             21             21   21      21      21
# 222,196                             36             36   36      36      36
# 230,290                             20             20   20      20      20
# 236,629                             19             19   19      19      19
# 237,656                             32             32   32      32      32
# 239,409                             13             13   13      13      13
# 239,554                             19             19   19      19      19
# 241,476                             22             22   22      22      22
# 244,387                             22             22   22      22      22
# 246,074                             16             16   16      16      16
# 246,288                             20             20   20      20      20
# 249,797                             15             15   15      15      15
# 251,818                             21             21   21      21      21
# 253,465                             18             18   18      18      18
# 253,957                             19             19   19      19      19
# 261,306                             15             15   15      15      15
# 261,756                             12             12   12      12      12
# 264,249                             33             33   33      33      33
# 264,604                             12             12   12      12      12
# 265,017                             28             28   28      28      28
# 265,615                             18             18   18      18      18
# 268,519                             23             23   23      23      23
# 271,219                              3              3    3       3       3
# 275,089                             19             19   19      19      19
# 275,312                             16             16   16      16      16
# 280,549                             15             15   15      15      15
# 284,031                             22             22   22      22      22
# 284,853                             25             25   25      25      25
# 294,217                             19             19   19      19      19
# 302,585                             18             18   18      18      18
# 306,345                             18             18   18      18      18
# 308,593                             24             24   24      24      24
# 313,532                             15             15   15      15      15
# 326,452                             20             20   20      20      20
# 330,061                             11             11   11      11      11
# 343,253                             29             29   29      29      29
# 377,550                             16             16   16      16      16
# 378,884                             16             16   16      16      16
#
#                         Body mass index  Absenteeism time in hours
# Work load Average/day
# 205,917                              21                         21
# 222,196                              36                         36
# 230,290                              20                         20
# 236,629                              19                         19
# 237,656                              32                         32
# 239,409                              13                         13
# 239,554                              19                         19
# 241,476                              22                         22
# 244,387                              22                         22
# 246,074                              16                         16
# 246,288                              20                         20
# 249,797                              15                         15
# 251,818                              21                         21
# 253,465                              18                         18
# 253,957                              19                         19
# 261,306                              15                         15
# 261,756                              12                         12
# 264,249                              33                         33
# 264,604                              12                         12
# 265,017                              28                         28
# 265,615                              18                         18
# 268,519                              23                         23
# 271,219                               3                          3
# 275,089                              19                         19
# 275,312                              16                         16
# 280,549                              15                         15
# 284,031                              22                         22
# 284,853                              25                         25
# 294,217                              19                         19
# 302,585                              18                         18
# 306,345                              18                         18
# 308,593                              24                         24
# 313,532                              15                         15
# 326,452                              20                         20
# 330,061                              11                         11
# 343,253                              29                         29
# 377,550                              16                         16
# 378,884                              16                         16

# %%
# data["Work load Average/day" ].value_counts()

# %%
data.plot.scatter(x="Work load Average/day ", y="Absenteeism time in hours")
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='Work load Average/day ', ylabel='Absenteeism time in hours'>

# %%
plt.bar(x=data["Work load Average/day "], height=data["Absenteeism time in hours"],width=0.8)
# Out:
# <BarContainer object of 740 artists>

# %%
# no effect

# %%
data.groupby(['Hit target']).count()
# Out:
#              ID  Reason for absence  Month of absence  Day of the week  \
# Hit target
# 81           19                  19                19               19
# 87           12                  12                12               12
# 88           28                  28                28               28
# 91           45                  45                45               45
# 92           79                  79                79               79
# 93          105                 105               105              105
# 94           34                  34                34               34
# 95           75                  75                75               75
# 96           75                  75                75               75
# 97           89                  89                89               89
# 98           66                  66                66               66
# 99          102                 102               102              102
# 100          11                  11                11               11
#
#             Seasons  Transportation expense  Distance from Residence to Work  \
# Hit target
# 81               19                      19                               19
# 87               12                      12                               12
# 88               28                      28                               28
# 91               45                      45                               45
# 92               79                      79                               79
# 93              105                     105                              105
# 94               34                      34                               34
# 95               75                      75                               75
# 96               75                      75                               75
# 97               89                      89                               89
# 98               66                      66                               66
# 99              102                     102                              102
# 100              11                      11                               11
#
#             Service time  Age  Work load Average/day   Disciplinary failure  \
# Hit target
# 81                    19   19                      19                    19
# 87                    12   12                      12                    12
# 88                    28   28                      28                    28
# 91                    45   45                      45                    45
# 92                    79   79                      79                    79
# 93                   105  105                     105                   105
# 94                    34   34                      34                    34
# 95                    75   75                      75                    75
# 96                    75   75                      75                    75
# 97                    89   89                      89                    89
# 98                    66   66                      66                    66
# 99                   102  102                     102                   102
# 100                   11   11                      11                    11
#
#             Education  Son  Social drinker  Social smoker  Pet  Weight  \
# Hit target
# 81                 19   19              19             19   19      19
# 87                 12   12              12             12   12      12
# 88                 28   28              28             28   28      28
# 91                 45   45              45             45   45      45
# 92                 79   79              79             79   79      79
# 93                105  105             105            105  105     105
# 94                 34   34              34             34   34      34
# 95                 75   75              75             75   75      75
# 96                 75   75              75             75   75      75
# 97                 89   89              89             89   89      89
# 98                 66   66              66             66   66      66
# 99                102  102             102            102  102     102
# 100                11   11              11             11   11      11
#
#             Height  Body mass index  Absenteeism time in hours
# Hit target
# 81              19               19                         19
# 87              12               12                         12
# 88              28               28                         28
# 91              45               45                         45
# 92              79               79                         79
# 93             105              105                        105
# 94              34               34                         34
# 95              75               75                         75
# 96              75               75                         75
# 97              89               89                         89
# 98              66               66                         66
# 99             102              102                        102
# 100             11               11                         11

# %%
data["Hit target"].value_counts()
# Out:
# 93     105
# 99     102
# 97      89
# 92      79
# 95      75
# 96      75
# 98      66
# 91      45
# 94      34
# 88      28
# 81      19
# 87      12
# 100     11
# Name: Hit target, dtype: int64

# %%
data.plot.scatter(x="Hit target", y="Absenteeism time in hours")
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='Hit target', ylabel='Absenteeism time in hours'>

# %%
plt.bar(x=data["Hit target"], height=data["Absenteeism time in hours"],width=0.8)
# Out:
# <BarContainer object of 740 artists>

# %%
# equal propertion almost and nothing can be predicted here

# %%
data.groupby(['Disciplinary failure']).count()
# Out:
#                        ID  Reason for absence  Month of absence  \
# Disciplinary failure
# 0                     700                 700               700
# 1                      40                  40                40
#
#                       Day of the week  Seasons  Transportation expense  \
# Disciplinary failure
# 0                                 700      700                     700
# 1                                  40       40                      40
#
#                       Distance from Residence to Work  Service time  Age  \
# Disciplinary failure
# 0                                                 700           700  700
# 1                                                  40            40   40
#
#                       Work load Average/day   Hit target  Education  Son  \
# Disciplinary failure
# 0                                        700         700        700  700
# 1                                         40          40         40   40
#
#                       Social drinker  Social smoker  Pet  Weight  Height  \
# Disciplinary failure
# 0                                700            700  700     700     700
# 1                                 40             40   40      40      40
#
#                       Body mass index  Absenteeism time in hours
# Disciplinary failure
# 0                                 700                        700
# 1                                  40                         40

# %%
data["Disciplinary failure"].value_counts()
# Out:
# 0    700
# 1     40
# Name: Disciplinary failure, dtype: int64

# %%
data.plot.scatter(x="Disciplinary failure", y="Absenteeism time in hours")
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='Disciplinary failure', ylabel='Absenteeism time in hours'>

# %%
plt.bar(x=data["Disciplinary failure"], height=data["Absenteeism time in hours"],width=0.8)
# Out:
# <BarContainer object of 740 artists>

# %%
# ntohing here which means when they work all employess follow the rules, important to notice

# %%
data.groupby(['Education']).count()
# Out:
#             ID  Reason for absence  Month of absence  Day of the week  \
# Education
# 1          611                 611               611              611
# 2           46                  46                46               46
# 3           79                  79                79               79
# 4            4                   4                 4                4
#
#            Seasons  Transportation expense  Distance from Residence to Work  \
# Education
# 1              611                     611                              611
# 2               46                      46                               46
# 3               79                      79                               79
# 4                4                       4                                4
#
#            Service time  Age  Work load Average/day   Hit target  \
# Education
# 1                   611  611                     611         611
# 2                    46   46                      46          46
# 3                    79   79                      79          79
# 4                     4    4                       4           4
#
#            Disciplinary failure  Son  Social drinker  Social smoker  Pet  \
# Education
# 1                           611  611             611            611  611
# 2                            46   46              46             46   46
# 3                            79   79              79             79   79
# 4                             4    4               4              4    4
#
#            Weight  Height  Body mass index  Absenteeism time in hours
# Education
# 1             611     611              611                        611
# 2              46      46               46                         46
# 3              79      79               79                         79
# 4               4       4                4                          4

# %%
data["Education"].value_counts()
# Out:
# 1    611
# 3     79
# 2     46
# 4      4
# Name: Education, dtype: int64

# %%
data.plot.scatter(x="Education", y="Absenteeism time in hours")
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='Education', ylabel='Absenteeism time in hours'>

# %%
plt.bar(x=data["Education"], height=data["Absenteeism time in hours"],width=0.8)
# Out:
# <BarContainer object of 740 artists>

# %%
# this clearly shows if you hire more employees who have studied till high school, u will get more out of it.( as per predicted it).
# but also then most emloyees are more primary, and doing their work so its data analysis could lead to more results, as less data available for 
# 3 otherr classes

# %%
data.groupby(['Son']).count()
# Out:
#       ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# Son
# 0    298                 298               298              298      298
# 1    229                 229               229              229      229
# 2    156                 156               156              156      156
# 3     15                  15                15               15       15
# 4     42                  42                42               42       42
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# Son
# 0                       298                              298           298
# 1                       229                              229           229
# 2                       156                              156           156
# 3                        15                               15            15
# 4                        42                               42            42
#
#      Age  Work load Average/day   Hit target  Disciplinary failure  Education  \
# Son
# 0    298                     298         298                   298        298
# 1    229                     229         229                   229        229
# 2    156                     156         156                   156        156
# 3     15                      15          15                    15         15
# 4     42                      42          42                    42         42
#
#      Social drinker  Social smoker  Pet  Weight  Height  Body mass index  \
# Son
# 0               298            298  298     298     298              298
# 1               229            229  229     229     229              229
# 2               156            156  156     156     156              156
# 3                15             15   15      15      15               15
# 4                42             42   42      42      42               42
#
#      Absenteeism time in hours
# Son
# 0                          298
# 1                          229
# 2                          156
# 3                           15
# 4                           42

# %%
data["Son"].value_counts()
# Out:
# 0    298
# 1    229
# 2    156
# 4     42
# 3     15
# Name: Son, dtype: int64

# %%
data.plot.scatter(x="Son", y="Absenteeism time in hours")
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='Son', ylabel='Absenteeism time in hours'>

# %%
plt.bar(x=data["Son"], height=data["Absenteeism time in hours"],width=0.8)
# Out:
# <BarContainer object of 740 artists>

# %%
# It can be said ppl with more childrn above 2 tend to be more hard working compared to less children which is understable( less data to analyze)
# Also not too concreate as many still worl( less absent ) but its just a comparision( which related to old age emplyees more efficent then mid thirties)

# %%
data.groupby(['Social drinker']).count()
# Out:
#                  ID  Reason for absence  Month of absence  Day of the week  \
# Social drinker
# 0               320                 320               320              320
# 1               420                 420               420              420
#
#                 Seasons  Transportation expense  \
# Social drinker
# 0                   320                     320
# 1                   420                     420
#
#                 Distance from Residence to Work  Service time  Age  \
# Social drinker
# 0                                           320           320  320
# 1                                           420           420  420
#
#                 Work load Average/day   Hit target  Disciplinary failure  \
# Social drinker
# 0                                  320         320                   320
# 1                                  420         420                   420
#
#                 Education  Son  Social smoker  Pet  Weight  Height  \
# Social drinker
# 0                     320  320            320  320     320     320
# 1                     420  420            420  420     420     420
#
#                 Body mass index  Absenteeism time in hours
# Social drinker
# 0                           320                        320
# 1                           420                        420

# %%
data["Social drinker"].value_counts()
# Out:
# 1    420
# 0    320
# Name: Social drinker, dtype: int64

# %%
data.plot.scatter(x="Social drinker", y="Absenteeism time in hours")
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='Social drinker', ylabel='Absenteeism time in hours'>

# %%
plt.bar(x=data["Social drinker"], height=data["Absenteeism time in hours"],width=0.8)
# Out:
# <BarContainer object of 740 artists>

# %%
# nothing can be deciphered here

# %%
data.groupby(['Social smoker']).count()
# Out:
#                 ID  Reason for absence  Month of absence  Day of the week  \
# Social smoker
# 0              686                 686               686              686
# 1               54                  54                54               54
#
#                Seasons  Transportation expense  \
# Social smoker
# 0                  686                     686
# 1                   54                      54
#
#                Distance from Residence to Work  Service time  Age  \
# Social smoker
# 0                                          686           686  686
# 1                                           54            54   54
#
#                Work load Average/day   Hit target  Disciplinary failure  \
# Social smoker
# 0                                 686         686                   686
# 1                                  54          54                    54
#
#                Education  Son  Social drinker  Pet  Weight  Height  \
# Social smoker
# 0                    686  686             686  686     686     686
# 1                     54   54              54   54      54      54
#
#                Body mass index  Absenteeism time in hours
# Social smoker
# 0                          686                        686
# 1                           54                         54

# %%
data["Social smoker"].value_counts()
# Out:
# 0    686
# 1     54
# Name: Social smoker, dtype: int64

# %%
data.plot.scatter(x="Social smoker", y="Absenteeism time in hours")
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='Social smoker', ylabel='Absenteeism time in hours'>

# %%
plt.bar(x=data["Social smoker"], height=data["Absenteeism time in hours"],width=0.8)
# Out:
# <BarContainer object of 740 artists>

# %%
# This clearly suggest many ppl dont smoke, and even some do doesnt have adverse affect on their work as it can be seen here.

# %%
data.groupby(['Pet']).count()
# Out:
#       ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# Pet
# 0    460                 460               460              460      460
# 1    138                 138               138              138      138
# 2     96                  96                96               96       96
# 4     32                  32                32               32       32
# 5      6                   6                 6                6        6
# 8      8                   8                 8                8        8
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# Pet
# 0                       460                              460           460
# 1                       138                              138           138
# 2                        96                               96            96
# 4                        32                               32            32
# 5                         6                                6             6
# 8                         8                                8             8
#
#      Age  Work load Average/day   Hit target  Disciplinary failure  Education  \
# Pet
# 0    460                     460         460                   460        460
# 1    138                     138         138                   138        138
# 2     96                      96          96                    96         96
# 4     32                      32          32                    32         32
# 5      6                       6           6                     6          6
# 8      8                       8           8                     8          8
#
#      Son  Social drinker  Social smoker  Weight  Height  Body mass index  \
# Pet
# 0    460             460            460     460     460              460
# 1    138             138            138     138     138              138
# 2     96              96             96      96      96               96
# 4     32              32             32      32      32               32
# 5      6               6              6       6       6                6
# 8      8               8              8       8       8                8
#
#      Absenteeism time in hours
# Pet
# 0                          460
# 1                          138
# 2                           96
# 4                           32
# 5                            6
# 8                            8

# %%
data["Pet"].value_counts()
# Out:
# 0    460
# 1    138
# 2     96
# 4     32
# 8      8
# 5      6
# Name: Pet, dtype: int64

# %%
data.plot.scatter(x="Pet", y="Absenteeism time in hours")
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='Pet', ylabel='Absenteeism time in hours'>

# %%
plt.bar(x=data["Pet"], height=data["Absenteeism time in hours"],width=0.8)
# Out:
# <BarContainer object of 740 artists>

# %%
data.groupby(['Weight']).count()
# Out:
#          ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# Weight
# 56       46                  46                46               46       46
# 58        7                   7                 7                7        7
# 63       20                  20                20               20       20
# 65       61                  61                61               61       61
# 67       30                  30                30               30       30
# 68       13                  13                13               13       13
# 69       85                  85                85               85       85
# 70       15                  15                15               15       15
# 73       37                  37                37               37       37
# 75       19                  19                19               19       19
# 76        3                   3                 3                3        3
# 77        6                   6                 6                6        6
# 79        3                   3                 3                3        3
# 80       24                  24                24               24       24
# 83       55                  55                55               55       55
# 84       16                  16                16               16       16
# 86       24                  24                24               24       24
# 88       29                  29                29               29       29
# 89      113                 113               113              113      113
# 90       40                  40                40               40       40
# 94        4                   4                 4                4        4
# 95       29                  29                29               29       29
# 98       35                  35                35               35       35
# 100       2                   2                 2                2        2
# 106      19                  19                19               19       19
# 108       5                   5                 5                5        5
#
#         Transportation expense  Distance from Residence to Work  Service time  \
# Weight
# 56                          46                               46            46
# 58                           7                                7             7
# 63                          20                               20            20
# 65                          61                               61            61
# 67                          30                               30            30
# 68                          13                               13            13
# 69                          85                               85            85
# 70                          15                               15            15
# 73                          37                               37            37
# 75                          19                               19            19
# 76                           3                                3             3
# 77                           6                                6             6
# 79                           3                                3             3
# 80                          24                               24            24
# 83                          55                               55            55
# 84                          16                               16            16
# 86                          24                               24            24
# 88                          29                               29            29
# 89                         113                              113           113
# 90                          40                               40            40
# 94                           4                                4             4
# 95                          29                               29            29
# 98                          35                               35            35
# 100                          2                                2             2
# 106                         19                               19            19
# 108                          5                                5             5
#
#         Age  Work load Average/day   Hit target  Disciplinary failure  \
# Weight
# 56       46                      46          46                    46
# 58        7                       7           7                     7
# 63       20                      20          20                    20
# 65       61                      61          61                    61
# 67       30                      30          30                    30
# 68       13                      13          13                    13
# 69       85                      85          85                    85
# 70       15                      15          15                    15
# 73       37                      37          37                    37
# 75       19                      19          19                    19
# 76        3                       3           3                     3
# 77        6                       6           6                     6
# 79        3                       3           3                     3
# 80       24                      24          24                    24
# 83       55                      55          55                    55
# 84       16                      16          16                    16
# 86       24                      24          24                    24
# 88       29                      29          29                    29
# 89      113                     113         113                   113
# 90       40                      40          40                    40
# 94        4                       4           4                     4
# 95       29                      29          29                    29
# 98       35                      35          35                    35
# 100       2                       2           2                     2
# 106      19                      19          19                    19
# 108       5                       5           5                     5
#
#         Education  Son  Social drinker  Social smoker  Pet  Height  \
# Weight
# 56             46   46              46             46   46      46
# 58              7    7               7              7    7       7
# 63             20   20              20             20   20      20
# 65             61   61              61             61   61      61
# 67             30   30              30             30   30      30
# 68             13   13              13             13   13      13
# 69             85   85              85             85   85      85
# 70             15   15              15             15   15      15
# 73             37   37              37             37   37      37
# 75             19   19              19             19   19      19
# 76              3    3               3              3    3       3
# 77              6    6               6              6    6       6
# 79              3    3               3              3    3       3
# 80             24   24              24             24   24      24
# 83             55   55              55             55   55      55
# 84             16   16              16             16   16      16
# 86             24   24              24             24   24      24
# 88             29   29              29             29   29      29
# 89            113  113             113            113  113     113
# 90             40   40              40             40   40      40
# 94              4    4               4              4    4       4
# 95             29   29              29             29   29      29
# 98             35   35              35             35   35      35
# 100             2    2               2              2    2       2
# 106            19   19              19             19   19      19
# 108             5    5               5              5    5       5
#
#         Body mass index  Absenteeism time in hours
# Weight
# 56                   46                         46
# 58                    7                          7
# 63                   20                         20
# 65                   61                         61
# 67                   30                         30
# 68                   13                         13
# 69                   85                         85
# 70                   15                         15
# 73                   37                         37
# 75                   19                         19
# 76                    3                          3
# 77                    6                          6
# 79                    3                          3
# 80                   24                         24
# 83                   55                         55
# 84                   16                         16
# 86                   24                         24
# 88                   29                         29
# 89                  113                        113
# 90                   40                         40
# 94                    4                          4
# 95                   29                         29
# 98                   35                         35
# 100                   2                          2
# 106                  19                         19
# 108                   5                          5

# %%
data["Weight"].value_counts()
# Out:
# 89     113
# 69      85
# 65      61
# 83      55
# 56      46
# 90      40
# 73      37
# 98      35
# 67      30
# 95      29
# 88      29
# 80      24
# 86      24
# 63      20
# 75      19
# 106     19
# 84      16
# 70      15
# 68      13
# 58       7
# 77       6
# 108      5
# 94       4
# 76       3
# 79       3
# 100      2
# Name: Weight, dtype: int64

# %%
data.plot.scatter(x="Weight", y="Absenteeism time in hours")
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='Weight', ylabel='Absenteeism time in hours'>

# %%
plt.bar(x=data["Weight"], height=data["Absenteeism time in hours"],width=0.8)
# Out:
# <BarContainer object of 740 artists>

# %%
# Here we have a clear pattern unfit ppl both ( high and low wt ) above 89 kgs andbelow 68 kgswith couple of also fit( for some wts which are healthy)

# %%
data.groupby(['Height']).count()
# Out:
#          ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# Height
# 163       6                   6                 6                6        6
# 165      24                  24                24               24       24
# 167      34                  34                34               34       34
# 168      48                  48                48               48       48
# 169      95                  95                95               95       95
# 170     166                 166               166              166      166
# 171      83                  83                83               83       83
# 172     155                 155               155              155      155
# 174       8                   8                 8                8        8
# 175       8                   8                 8                8        8
# 178      57                  57                57               57       57
# 182      20                  20                20               20       20
# 185       7                   7                 7                7        7
# 196      29                  29                29               29       29
#
#         Transportation expense  Distance from Residence to Work  Service time  \
# Height
# 163                          6                                6             6
# 165                         24                               24            24
# 167                         34                               34            34
# 168                         48                               48            48
# 169                         95                               95            95
# 170                        166                              166           166
# 171                         83                               83            83
# 172                        155                              155           155
# 174                          8                                8             8
# 175                          8                                8             8
# 178                         57                               57            57
# 182                         20                               20            20
# 185                          7                                7             7
# 196                         29                               29            29
#
#         Age  Work load Average/day   Hit target  Disciplinary failure  \
# Height
# 163       6                       6           6                     6
# 165      24                      24          24                    24
# 167      34                      34          34                    34
# 168      48                      48          48                    48
# 169      95                      95          95                    95
# 170     166                     166         166                   166
# 171      83                      83          83                    83
# 172     155                     155         155                   155
# 174       8                       8           8                     8
# 175       8                       8           8                     8
# 178      57                      57          57                    57
# 182      20                      20          20                    20
# 185       7                       7           7                     7
# 196      29                      29          29                    29
#
#         Education  Son  Social drinker  Social smoker  Pet  Weight  \
# Height
# 163             6    6               6              6    6       6
# 165            24   24              24             24   24      24
# 167            34   34              34             34   34      34
# 168            48   48              48             48   48      48
# 169            95   95              95             95   95      95
# 170           166  166             166            166  166     166
# 171            83   83              83             83   83      83
# 172           155  155             155            155  155     155
# 174             8    8               8              8    8       8
# 175             8    8               8              8    8       8
# 178            57   57              57             57   57      57
# 182            20   20              20             20   20      20
# 185             7    7               7              7    7       7
# 196            29   29              29             29   29      29
#
#         Body mass index  Absenteeism time in hours
# Height
# 163                   6                          6
# 165                  24                         24
# 167                  34                         34
# 168                  48                         48
# 169                  95                         95
# 170                 166                        166
# 171                  83                         83
# 172                 155                        155
# 174                   8                          8
# 175                   8                          8
# 178                  57                         57
# 182                  20                         20
# 185                   7                          7
# 196                  29                         29

# %%
data["Height"].value_counts()
# Out:
# 170    166
# 172    155
# 169     95
# 171     83
# 178     57
# 168     48
# 167     34
# 196     29
# 165     24
# 182     20
# 174      8
# 175      8
# 185      7
# 163      6
# Name: Height, dtype: int64

# %%
data.plot.scatter(x="Height", y="Absenteeism time in hours")
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='Height', ylabel='Absenteeism time in hours'>

# %%
plt.bar(x=data["Height"], height=data["Absenteeism time in hours"],width=0.8)
# Out:
# <BarContainer object of 740 artists>

# %%
# here it can be said ppl with high height tend to be more absent and irregular, ( ppl with 173 to 195 or below, no deata available )
# are pretty regular in their work

# %%
data.groupby(['Body mass index']).count()
# Out:
#                   ID  Reason for absence  Month of absence  Day of the week  \
# Body mass index
# 19                46                  46                46               46
# 21                22                  22                22               22
# 22                35                  35                35               35
# 23                75                  75                75               75
# 24                86                  86                86               86
# 25               126                 126               126              126
# 27                24                  24                24               24
# 28                59                  59                59               59
# 29                23                  23                23               23
# 30                40                  40                40               40
# 31               147                 147               147              147
# 32                24                  24                24               24
# 33                 6                   6                 6                6
# 34                 1                   1                 1                1
# 35                 2                   2                 2                2
# 36                 5                   5                 5                5
# 38                19                  19                19               19
#
#                  Seasons  Transportation expense  \
# Body mass index
# 19                    46                      46
# 21                    22                      22
# 22                    35                      35
# 23                    75                      75
# 24                    86                      86
# 25                   126                     126
# 27                    24                      24
# 28                    59                      59
# 29                    23                      23
# 30                    40                      40
# 31                   147                     147
# 32                    24                      24
# 33                     6                       6
# 34                     1                       1
# 35                     2                       2
# 36                     5                       5
# 38                    19                      19
#
#                  Distance from Residence to Work  Service time  Age  \
# Body mass index
# 19                                            46            46   46
# 21                                            22            22   22
# 22                                            35            35   35
# 23                                            75            75   75
# 24                                            86            86   86
# 25                                           126           126  126
# 27                                            24            24   24
# 28                                            59            59   59
# 29                                            23            23   23
# 30                                            40            40   40
# 31                                           147           147  147
# 32                                            24            24   24
# 33                                             6             6    6
# 34                                             1             1    1
# 35                                             2             2    2
# 36                                             5             5    5
# 38                                            19            19   19
#
#                  Work load Average/day   Hit target  Disciplinary failure  \
# Body mass index
# 19                                   46          46                    46
# 21                                   22          22                    22
# 22                                   35          35                    35
# 23                                   75          75                    75
# 24                                   86          86                    86
# 25                                  126         126                   126
# 27                                   24          24                    24
# 28                                   59          59                    59
# 29                                   23          23                    23
# 30                                   40          40                    40
# 31                                  147         147                   147
# 32                                   24          24                    24
# 33                                    6           6                     6
# 34                                    1           1                     1
# 35                                    2           2                     2
# 36                                    5           5                     5
# 38                                   19          19                    19
#
#                  Education  Son  Social drinker  Social smoker  Pet  Weight  \
# Body mass index
# 19                      46   46              46             46   46      46
# 21                      22   22              22             22   22      22
# 22                      35   35              35             35   35      35
# 23                      75   75              75             75   75      75
# 24                      86   86              86             86   86      86
# 25                     126  126             126            126  126     126
# 27                      24   24              24             24   24      24
# 28                      59   59              59             59   59      59
# 29                      23   23              23             23   23      23
# 30                      40   40              40             40   40      40
# 31                     147  147             147            147  147     147
# 32                      24   24              24             24   24      24
# 33                       6    6               6              6    6       6
# 34                       1    1               1              1    1       1
# 35                       2    2               2              2    2       2
# 36                       5    5               5              5    5       5
# 38                      19   19              19             19   19      19
#
#                  Height  Absenteeism time in hours
# Body mass index
# 19                   46                         46
# 21                   22                         22
# 22                   35                         35
# 23                   75                         75
# 24                   86                         86
# 25                  126                        126
# 27                   24                         24
# 28                   59                         59
# 29                   23                         23
# 30                   40                         40
# 31                  147                        147
# 32                   24                         24
# 33                    6                          6
# 34                    1                          1
# 35                    2                          2
# 36                    5                          5
# 38                   19                         19

# %%
data["Body mass index"].value_counts()
# Out:
# 31    147
# 25    126
# 24     86
# 23     75
# 28     59
# 19     46
# 30     40
# 22     35
# 32     24
# 27     24
# 29     23
# 21     22
# 38     19
# 33      6
# 36      5
# 35      2
# 34      1
# Name: Body mass index, dtype: int64

# %%
data.plot.scatter(x="Body mass index", y="Absenteeism time in hours")
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='Body mass index', ylabel='Absenteeism time in hours'>

# %%
plt.bar(x=data["Body mass index"], height=data["Absenteeism time in hours"],width=0.8)
# Out:
# <BarContainer object of 740 artists>

# %%
# nothing here ( even though here ppl with less weight and more height makes sense and less BMI ppl tend to be more absent)

# %%
corrM = data.corr()

# %%
corrM
# Out:
#                                        ID  Reason for absence  \
# ID                               1.000000           -0.064245
# Reason for absence              -0.064245            1.000000
# Month of absence                -0.000043           -0.083858
# Day of the week                  0.034468            0.116319
# Seasons                          0.098495           -0.117925
# Transportation expense          -0.224163           -0.119381
# Distance from Residence to Work -0.486160            0.161831
# Service time                    -0.272704            0.048425
# Age                              0.040899           -0.078608
# Hit target                       0.018789            0.088943
# Disciplinary failure             0.004502           -0.545054
# Education                       -0.036254           -0.047357
# Son                              0.002767           -0.055364
# Social drinker                  -0.451338            0.065441
# Social smoker                   -0.010826           -0.115702
# Pet                             -0.041418           -0.055911
# Weight                          -0.254222           -0.000269
# Height                           0.076363           -0.079267
# Body mass index                 -0.306924            0.037205
# Absenteeism time in hours       -0.017997           -0.173116
#
#                                  Month of absence  Day of the week   Seasons  \
# ID                                      -0.000043         0.034468  0.098495
# Reason for absence                      -0.083858         0.116319 -0.117925
# Month of absence                         1.000000        -0.006528  0.407770
# Day of the week                         -0.006528         1.000000  0.046493
# Seasons                                  0.407770         0.046493  1.000000
# Transportation expense                   0.137525         0.033988  0.036995
# Distance from Residence to Work         -0.003887         0.118026 -0.063108
# Service time                            -0.062862         0.021252 -0.010904
# Age                                     -0.001520         0.004459 -0.012089
# Hit target                              -0.460453         0.030986 -0.061154
# Disciplinary failure                     0.107946        -0.015120  0.151766
# Education                               -0.066128         0.058516 -0.002951
# Son                                      0.079031         0.098079  0.046950
# Social drinker                           0.056226         0.041772 -0.045982
# Social smoker                           -0.038603         0.013156 -0.048671
# Pet                                      0.047787        -0.028885  0.012356
# Weight                                   0.023278        -0.128980 -0.026278
# Height                                  -0.068942        -0.082133 -0.033737
# Body mass index                          0.051046        -0.103578 -0.011031
# Absenteeism time in hours                0.024345        -0.124361 -0.005615
#
#                                  Transportation expense  \
# ID                                            -0.224163
# Reason for absence                            -0.119381
# Month of absence                               0.137525
# Day of the week                                0.033988
# Seasons                                        0.036995
# Transportation expense                         1.000000
# Distance from Residence to Work                0.262183
# Service time                                  -0.349887
# Age                                           -0.227542
# Hit target                                    -0.080193
# Disciplinary failure                           0.109222
# Education                                     -0.055065
# Son                                            0.383001
# Social drinker                                 0.145117
# Social smoker                                  0.044356
# Pet                                            0.400080
# Weight                                        -0.207435
# Height                                        -0.194496
# Body mass index                               -0.136517
# Absenteeism time in hours                      0.027585
#
#                                  Distance from Residence to Work  \
# ID                                                     -0.486160
# Reason for absence                                      0.161831
# Month of absence                                       -0.003887
# Day of the week                                         0.118026
# Seasons                                                -0.063108
# Transportation expense                                  0.262183
# Distance from Residence to Work                         1.000000
# Service time                                            0.131730
# Age                                                    -0.145886
# Hit target                                             -0.013865
# Disciplinary failure                                   -0.056527
# Education                                              -0.259605
# Son                                                     0.054230
# Social drinker                                          0.452196
# Social smoker                                          -0.075369
# Pet                                                     0.205941
# Weight                                                 -0.047859
# Height                                                 -0.353372
# Body mass index                                         0.113772
# Absenteeism time in hours                              -0.088363
#
#                                  Service time       Age  Hit target  \
# ID                                  -0.272704  0.040899    0.018789
# Reason for absence                   0.048425 -0.078608    0.088943
# Month of absence                    -0.062862 -0.001520   -0.460453
# Day of the week                      0.021252  0.004459    0.030986
# Seasons                             -0.010904 -0.012089   -0.061154
# Transportation expense              -0.349887 -0.227542   -0.080193
# Distance from Residence to Work      0.131730 -0.145886   -0.013865
# Service time                         1.000000  0.670979   -0.007840
# Age                                  0.670979  1.000000   -0.039224
# Hit target                          -0.007840 -0.039224    1.000000
# Disciplinary failure                -0.000221  0.104304   -0.147971
# Education                           -0.213000 -0.221882    0.101062
# Son                                 -0.047128  0.056984   -0.014091
# Social drinker                       0.353141  0.213183   -0.102480
# Social smoker                        0.072424  0.121738    0.051254
# Pet                                 -0.440301 -0.231226    0.007201
# Weight                               0.455975  0.418730   -0.044947
# Height                              -0.053135 -0.062997    0.093267
# Body mass index                      0.499718  0.470688   -0.088939
# Absenteeism time in hours            0.019029  0.065760    0.026695
#
#                                  Disciplinary failure  Education       Son  \
# ID                                           0.004502  -0.036254  0.002767
# Reason for absence                          -0.545054  -0.047357 -0.055364
# Month of absence                             0.107946  -0.066128  0.079031
# Day of the week                             -0.015120   0.058516  0.098079
# Seasons                                      0.151766  -0.002951  0.046950
# Transportation expense                       0.109222  -0.055065  0.383001
# Distance from Residence to Work             -0.056527  -0.259605  0.054230
# Service time                                -0.000221  -0.213000 -0.047128
# Age                                          0.104304  -0.221882  0.056984
# Hit target                                  -0.147971   0.101062 -0.014091
# Disciplinary failure                         1.000000  -0.059298  0.072096
# Education                                   -0.059298   1.000000 -0.188622
# Son                                          0.072096  -0.188622  1.000000
# Social drinker                               0.051838  -0.420013  0.206376
# Social smoker                                0.116748   0.032727  0.156088
# Pet                                          0.018881  -0.053554  0.108917
# Weight                                       0.072225  -0.300574 -0.139552
# Height                                      -0.010498   0.100977 -0.014208
# Body mass index                              0.079428  -0.366884 -0.144150
# Absenteeism time in hours                   -0.124248  -0.046235  0.113756
#
#                                  Social drinker  Social smoker       Pet  \
# ID                                    -0.451338      -0.010826 -0.041418
# Reason for absence                     0.065441      -0.115702 -0.055911
# Month of absence                       0.056226      -0.038603  0.047787
# Day of the week                        0.041772       0.013156 -0.028885
# Seasons                               -0.045982      -0.048671  0.012356
# Transportation expense                 0.145117       0.044356  0.400080
# Distance from Residence to Work        0.452196      -0.075369  0.205941
# Service time                           0.353141       0.072424 -0.440301
# Age                                    0.213183       0.121738 -0.231226
# Hit target                            -0.102480       0.051254  0.007201
# Disciplinary failure                   0.051838       0.116748  0.018881
# Education                             -0.420013       0.032727 -0.053554
# Son                                    0.206376       0.156088  0.108917
# Social drinker                         1.000000      -0.111678 -0.122780
# Social smoker                         -0.111678       1.000000  0.105379
# Pet                                   -0.122780       0.105379  1.000000
# Weight                                 0.378664      -0.198511 -0.103770
# Height                                 0.169951       0.003271 -0.103143
# Body mass index                        0.323978      -0.196006 -0.076103
# Absenteeism time in hours              0.065067      -0.008936 -0.028277
#
#                                    Weight    Height  Body mass index  \
# ID                              -0.254222  0.076363        -0.306924
# Reason for absence              -0.000269 -0.079267         0.037205
# Month of absence                 0.023278 -0.068942         0.051046
# Day of the week                 -0.128980 -0.082133        -0.103578
# Seasons                         -0.026278 -0.033737        -0.011031
# Transportation expense          -0.207435 -0.194496        -0.136517
# Distance from Residence to Work -0.047859 -0.353372         0.113772
# Service time                     0.455975 -0.053135         0.499718
# Age                              0.418730 -0.062997         0.470688
# Hit target                      -0.044947  0.093267        -0.088939
# Disciplinary failure             0.072225 -0.010498         0.079428
# Education                       -0.300574  0.100977        -0.366884
# Son                             -0.139552 -0.014208        -0.144150
# Social drinker                   0.378664  0.169951         0.323978
# Social smoker                   -0.198511  0.003271        -0.196006
# Pet                             -0.103770 -0.103143        -0.076103
# Weight                           1.000000  0.306802         0.904117
# Height                           0.306802  1.000000        -0.121049
# Body mass index                  0.904117 -0.121049         1.000000
# Absenteeism time in hours        0.015789  0.144420        -0.049719
#
#                                  Absenteeism time in hours
# ID                                               -0.017997
# Reason for absence                               -0.173116
# Month of absence                                  0.024345
# Day of the week                                  -0.124361
# Seasons                                          -0.005615
# Transportation expense                            0.027585
# Distance from Residence to Work                  -0.088363
# Service time                                      0.019029
# Age                                               0.065760
# Hit target                                        0.026695
# Disciplinary failure                             -0.124248
# Education                                        -0.046235
# Son                                               0.113756
# Social drinker                                    0.065067
# Social smoker                                    -0.008936
# Pet                                              -0.028277
# Weight                                            0.015789
# Height                                            0.144420
# Body mass index                                  -0.049719
# Absenteeism time in hours                         1.000000

# %%
import seaborn as sns
sns.set(rc = {'figure.figsize':(15,8)})
ax = sns.heatmap(data.corr(), annot=True)

# %%
pair = {}

# %%
for i in range(0,20):
    columnName = data.columns[i]
    if i == 9:
        continue
    else:
        p = data['Absenteeism time in hours'].corr(data[columnName])
    if p>0:
        pair[columnName] = p
    print("Column Name:",columnName)
    print("Correlation:",p)
# Out:
# Column Name: ID
# Correlation: -0.017996593730977048
# Column Name: Reason for absence
# Correlation: -0.173115561460677
# Column Name: Month of absence
# Correlation: 0.02434535694486776
# Column Name: Day of the week
# Correlation: -0.12436061376972109
# Column Name: Seasons
# Correlation: -0.0056149810349652406
# Column Name: Transportation expense
# Correlation: 0.027584630997934113
# Column Name: Distance from Residence to Work
# Correlation: -0.08836282189613706
# Column Name: Service time
# Correlation: 0.019029261406040186
# Column Name: Age
# Correlation: 0.06575970132037087
# Column Name: Hit target
# Correlation: 0.026695064564031444
# Column Name: Disciplinary failure
# Correlation: -0.12424798409789004
# Column Name: Education
# Correlation: -0.046235223108760166
# Column Name: Son
# Correlation: 0.11375649558100596
# Column Name: Social drinker
# Correlation: 0.06506734280385368
# Column Name: Social smoker
# Correlation: -0.00893642314114111
# Column Name: Pet
# Correlation: -0.028276589052987685
# Column Name: Weight
# Correlation: 0.015789176536920323
# Column Name: Height
# Correlation: 0.14442047564277188
# Column Name: Body mass index
# Correlation: -0.04971947911291982

# %%
pair
# Out:
# {'Month of absence': 0.02434535694486776,
#  'Transportation expense': 0.027584630997934113,
#  'Service time': 0.019029261406040186,
#  'Age': 0.06575970132037087,
#  'Hit target': 0.026695064564031444,
#  'Son': 0.11375649558100596,
#  'Social drinker': 0.06506734280385368,
#  'Weight': 0.015789176536920323,
#  'Height': 0.14442047564277188}

# %%
# Certain statistical procedure to understand some features and get more analysis on them

# %%
# TRAINING IN A MODEL TO UNDERSTAND THE FEATURES AND THEIR IMPORTANCE BETTER, INITIALLY USING ALL FEATURES, ,'Work load Average/day '

# %%
X = data.drop(['Absenteeism time in hours','Work load Average/day '],axis=1)
Y = data['Absenteeism time in hours']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.1,random_state=42)

# %%
from xgboost import XGBClassifier

# %%
xgb_model = XGBClassifier(random_state = 0 ,use_label_encoder=True)
xgb_model.fit(X_train, Y_train)

print("Feature Importances : ", xgb_model.feature_importances_)
# Out:
# [16:23:11] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# C:\Users\amans\Anaconda3\envs\Aman2\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Feature Importances :  [0.05496149 0.13171394 0.04444498 0.03330317 0.03792406 0.08299909
#  0.04782849 0.06194666 0.04582866 0.03772642 0.         0.03127461
#  0.06219167 0.0716052  0.07485344 0.05064571 0.04702096 0.04830525
#  0.03542608]

# %%
# interms of feature importance - reason,transportation,smoker,drinker,son, service time

# %%
data.columns
# Out:
# Index(['ID', 'Reason for absence', 'Month of absence', 'Day of the week',
#        'Seasons', 'Transportation expense', 'Distance from Residence to Work',
#        'Service time', 'Age', 'Work load Average/day ', 'Hit target',
#        'Disciplinary failure', 'Education', 'Son', 'Social drinker',
#        'Social smoker', 'Pet', 'Weight', 'Height', 'Body mass index',
#        'Absenteeism time in hours'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()

# %%
lm.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
predictions = lm.predict(X_test)
from sklearn import metrics
y_pred = lm.predict(X_test)
# print("Accuracy:",metrics.accuracy_score(Y_test, y_pred))
print('Mean Absolute Error:', metrics.mean_absolute_error(Y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(Y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(Y_test, y_pred)))
# Out:
# Mean Absolute Error: 4.121524081793184
# Mean Squared Error: 31.340903164922597
# Root Mean Squared Error: 5.598294665781947

# %%
# ML procedure
